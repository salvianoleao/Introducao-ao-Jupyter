# %% [markdown]
# <img src="Figs/Logo_IF.png" alt="drawing" width="80%"/>
#
#
# <!--
#
# <img href="Figs/Logo_IF.png" style="width: 80%;" /> doesn't work
#
# ![Logotipo do IF](../Figs/Cab_IF_Red_01.png){ width=50% }
#
# <h1> <span style="color:blue">Curso de Python </span> </h1>
# -->
#
# <p style="margin-bottom:1cm;"> </p>
#
#
# <center> <font size="6" color="blue">Curso de Python</font> </center>
#
#
# <font size="4" color="blue">**Prof. :** Salviano A. Leão -- Instituto de Física - UFG-GO</font>

# %% [markdown]
# # A biblioteca matplotlib

# %% [markdown]
# Para um visão geral da capacidade dad biblioteca [matplotlib](http://matplotlib.org/) consulte a galeria de [demos](http://matplotlib.org/gallery.html).  Boa parte dos exmplos apresentado aqui foram da galeria de demos da matplotlib.

# %% [markdown]
# ## Sumário
#
# - [Visualizando os Dados](#Visualizando-os-Dados)
# - [Matplotlib usando a Pylab](#Matplotlib-usando-a-Pylab)
#   - [Matplotlib e Pylab](#Matplotlib-e-Pylab)
#   - [Primeiro exemplo](#Primeiro-exemplo)
#   - [Como importar matplotlib, pylab, pyplot, numpy e tudo mais](#Imp-Matplotlib)
# - [Mode inline do IPython](#Mode-inline-do-IPython)
# - [Salvando a figura em um arquivo](#Salvando-a-figura-em-um-arquivo)
# - [Modo interativo](#Modo-interativo)
# - [Ajustes finos dos gráficos](#Ajustes-finos-dos-gráficos)
# - [Fazendo o gráfico de mais de uma curva](#Fazendo-o-gráfico-de-mais-de-uma-curva)
# - [Três gráficos com um único eixo](#Três-gráficos-com-um-único-eixo)
# - [Ilustração do teorema de Bolzano](#Ilustração-do-teorema-de-Bolzano)
# - [Legendas e LaTeX](#Legendas-e-LaTeX)
# - [Coordenadas polares](#Coordenadas-polares)
# - [Dipolo elétrico](#Dipolo-elétrico)
# - [Histogramas](#Histogramas)
# - [Função integral do cosseno e seno](#Função-integral-do-cosseno-e-seno)
# - [Curvas Preenchidas](#Curvas-Preenchidas)
# - [Linhas multicoloridas](#Linhas-multicoloridas)
# - [Campos vetoriais](#Campos-vetoriais)
# - [Equação de Van der Pol](#Equação-de-Van-der-Pol)
# - [Visualizando dados matriciais](#Visualizando-dados-matriciais)
# - [Gráficos 3D](#Gráficos-3D)
# - [Curvaturas Gaussianas](#Curvaturas-Gaussianas)
# - [Módulo de animação da Matplotlib](#MPL-Mod-Anim)

# %% [markdown]
# Visualizando os Dados
# ================
#
#
# A finalidade da computação científica é a compreensão do modelo usado e não os números: Para entender o significado dos (muitos) números que calculamos, muitas vezes precisamos de pós-processamento, análise estatística e visualização gráfica dos nossos dados. As seções a seguir descrevem:
#
# - Matplotlib/Pylab - que nos permite gerar gráficos de alta qualidade do tipo *y*=*f*(*x*) (e um pouco mais)
#
# - Visual Python - que é uma ferramenta muito útil para gerar rapidamente animações de processos dependentes do tempo ocorrendo no espaço 3d.
#
#
# Matplotlib usando a Pylab
# --------------------------------------------------
#
# A biblioteca *Matplotlib* do Python é uma biblioteca para fazer gráficos 2D em python que produz figuras com qualidade para publicação em uma variedade de formatos impressos e ambientes interativos. A Matplotlib tenta fazer coisas fáceis e difíceis em coisas possíveis. Você pode gerar gráficos, histogramas, espectros de energia, gráficos de barras, diagramas de erro, gráficos de dispersão, etc, com apenas algumas linhas de código.
#
# Para obter informações mais detalhadas, consulte estes links
#
# - Uma introdução muito agradável na interface orientada a objetos Matplotlib, e um resumo de todas as formas importantes de mudança de estilo, tamanho de figura, largura de linha, etc Esta é uma referência útil: <http://nbviewer.ipython.org/urls/raw.github.com/jrjohansson/scientific-python-lectures/master/Lecture-4-Matplotlib.ipynb>
#
# - Matplotlib tutorial  <http://matplotlib.org/2.0.0/contents.html>
#
# - Página inicial do Matplotlib  <http://matplotlib.org/>
#
# - Galeria de exemplos [Matplotlib Gallery](https://github.com/rasbt/matplotlib-gallery)
#
# - Lista de exemplos de captura de tela simples <http://matplotlib.sourceforge.net/users/screenshots.html>
#
# - Galeria de miniaturas em extensão dos exemplos <http://matplotlib.sourceforge.net/gallery.html>
#
#
# ### Matplotlib e Pylab
#
# A Matplotlib *é uma biblioteca orientada a objetos para fazer gráficos*. A Pylab é uma interface para o mesmo conjunto de funções que imita a interface de traçado (state-driven) do Matlab.
#
# Pylab é ligeiramente mais conveniente de usar-se para gráficos simples e fáceis, enquanto a Matplotlib fornece um maior controle sobre todos os detalhado de como os gráficos são criados. Se você usar Matplotlib rotineiramente para produzir figuras, é mais aconselhavel aprender sobre a interface orientada a objetos da matplotlib (em vez da interface pylab).
#
# Este texto foca na interface Pylab.
#
# Uma excelente introdução e visão geral da interface gráficos da Matplotlib está disponível em <http://nbviewer.ipython.org/urls/raw.github.com/jrjohansson/scientific-python-lectures/master/Lecture-4-Matplotlib.ipynb> .
#
# Abaixo mostramos como obter a lista de terminais que a matplotlib reconhece:

# %%
# %matplotlib --list

# %% [markdown]
# Para obter algumas informações importantes a respeito da versão e o local da instalção que está sendo usada faça

# %%
# Para descobrir a versão da biblioteca faça
import matplotlib as mpl
mpl.__version__

# %%
# Para obter informações do local da instalção
mpl.__file__

# %%
# Para obter a localização do diretório de configuração
mpl.get_configdir()

# %%
# # Para obter a localização do diretório de cache
mpl.get_cachedir()

# %% [markdown]
# ### Primeiro exemplo
#
# A maneira recomendada de usar Matplotlib em um exemplo simples é mostrada aqui (vamos chamar este exemplo 1a):

# %%
# permite que se mostre os gráficos nesse ambiente
#%matplotlib gtk3
#%matplotlib inline
# %matplotlib qt5

# %%
# exemplo 1a
import numpy as np                  # obtém acesso aos rápidos arrays da numpy 
import matplotlib.pyplot as plt     # Para fazer os gráficos das funções

x0 = -2*np.pi     # Valor inicial de x
xf = +2*np.pi     # Valor final de x
dx = 0.01         # Passo da discretização dx = (xf - x0)/(np-1)

x = np.arange(x0, xf, dx)           # cria um vetor de dados x-data
y = np.sin(x)                       # calcula o vetor de dados y-data da função dada
plt.plot(x, y)                      # Faz o gráfico da função dada

# %%
? matplotlib

# %%
dir(plt)

# %% [markdown]
# Agora vamos abrir um console qt e fazer esse mesmo gráfico fora dessa janela, e para forçar janelas pop-up em vez de usar `%matplotlib inline`, use `%matplotlib qt`. Assim

# %%
# %matplotlib qt5
plt.plot(x, y)                      # Faz o gráfico anterior na janela pop-up

# %%
# vamos voltar a usar os gráficos internamente, para isso
# %matplotlib inline

# %% [markdown]
# O código magic `%load url` carrega o código diretamente na célula. Você pode escolher um arquivo ou arquivo local na web.
#
# O código abaixo e executar, ele irá substituir o conteúdo da célula pelo conteúdo do arquivo.

# %%
# %load https://matplotlib.org/_downloads/subplot3d.py
'''
====================
3D plots as subplots
====================

Demonstrate including 3D plots as subplots.
'''

import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from mpl_toolkits.mplot3d.axes3d import get_test_data
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


# set up a figure twice as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.5))

#===============
#  First subplot
#===============
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')

# plot a 3D surface like in the example mplot3d/surface3d_demo
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=10)

#===============
# Second subplot
#===============
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')

# plot a 3D wireframe like in the example mplot3d/wire3d_demo
X, Y, Z = get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

# %%
# %load https://matplotlib.org/_downloads/polygon_selector_demo.py

# %%
# %load https://matplotlib.org/_downloads/slider_demo.py

# %%
# %load https://matplotlib.org/_downloads/spine_placement_demo.py

# %%
#sphx-glr-gallery-ticks-and-spines-spine-placement-demo-py
# %load https://matplotlib.org/gallery/ticks_and_spines/spine_placement_demo.html

# %%
# %load http://matplotlib.org/mpl_examples/pylab_examples/contour_demo.py

# %% [markdown]
# ### Como importar matplotlib, pylab, pyplot, numpy e tudo mais  <a name="Imp-Matplotlib"></a>
#
# O submódulo `matplotlib.pyplot` fornece uma interface orientada a objetos para a biblioteca de construção de gráficos. Muitos dos exemplos na documentação da matplotlib seguem a convenção de importação para importar `matplotlib.pyplot` como `plt` e `numpy` como `np`. É claro que é decisão inteiramente do usuário se ele vai importar a biblioteca `numpy` sob o nome `np` (como muitas vezes feito em exemplos matplotlib) ou como outro nome qualque a gosto do usuário. Nesse caso é recomendado que o usuário crie um padrão e mantenha ele, assim evitará problemas de portabilidade do seus códigos no futuro. Da mesma forma, é uma questão de gosto se o submodule gráficos (`matplotlib.pyplot`) são importados como `plt` como é feito na documentação matplotlib ou `plot` (o que poderia ser argumentado é um pouco mais claro), etc.

# %% [markdown]
# Como sempre um equilíbrio tem que ser encontrado entre preferências pessoais e consistência com prática comum em escolher estes nome. A coerência com o uso comum é naturalmente mais importante se o código é susceptível de ser utilizado por outros ou se ele for publicado.
#
# Fazer um gráfico quase sempre necessita de matrizes de dados numéricos e é por isso que o módulo `numpy` é usado muito: ele fornece um gerenciamento de matriz muito rápido e eficiente para Python (ver [capítulo 15](15-numpy.ipynb)).
#
# Poderíamos também ter escrito o exemplo 1a acima como no exemplo 1b (que é idêntico em funcionalidade ao exemplo acima e criará o mesmo gráfico):

# %%
# Exemplo 1b
import pylab
import numpy as np  # Usando um novo nome para a NumPy

x = np.arange (-3.14, 3.14, 0.01)
y = np.sin(x)

pylab.plot(x, y)
pylab.plot(x, np.cos(x))

# %% [markdown]
# Como os objetos `numpy.arange` e `numpy.sin` já foram importados para o espaço de nomes (conveniência) `pylab`, também podemos escrevê-lo como exemplo 1c:

# %%
# Exemplo 1c
import pylab as plt

x = plt.arange(-3.14, 3.14, 0.01)
y = plt.sin(x)
xmin = -3.0
xmax = +3.0
ymin = -1.0
ymax = +1.0
v = [xmin, xmax, ymin, ymax] # lista contendo os intervalos do gráficos
plt.axis(v)                  # lista contendo os intevalos dos eixos 
#plt.grid(b='on',axis='both')
plt.grid()
plt.plot(x, y)
plt.show()

# %%
? plt.axis

# %% [markdown]
# Se realmente queremos digitar menos caracteres, também poderíamos importar toda a funcionalidade do módulo de conveniência `pylab` e reescrever o código como exemplo 1d:

# %%
#exemplo 1 d
# Essa é exemplo de como não fazer
from pylab import *  # Em geral não é recomendada essa prática
                     # aqui, para um teste interativo, passa 

x = arange(-3.14, 3.14, 0.01)
y = sin(x)
plot(x, y)

show()

# %% [markdown]
# Isso pode ser extremamente conveniente, mas vem com um grande aviso de perigo:
#
# - Ao usar `from pylab import *` é aceitável no prompt de comando para criar interativamente gráficos e analisar dados, isso nunca deve ser usado em qualquer script para fazer gráficos.
#
# - O nível mais alto do pylab fornece mais de 800 objetos diferentes que são todos importados para o espaço de nome global ao executar `from pylab import *`. Isso não é uma boa prática e pode entrar em conflito com outros objetos que já existem ou que serão criados posteriormente.
#
# - Como regra geral: nunca utilize `from alguma_biblioteca import *` nos programas que serão usados posteriormente. Isso pode funcionar no prompt de comando, entretanto, não se deve usar, pois pode representar uma série de potenciais bugs em seu código.
#
# Nos exemplos a seguir, geralmente usamos a interface `pylab` para as rotinas para fazer gráficos, mas isso é puramente uma questão de gosto e hábito e de nenhuma maneira a única maneira (note que os autores da Matplotlib recomendam o estilo de importação como no exemplo 1a, veja Também [Matplot FAQ entrada](http://matplotlib.org/faq/): [Matplotlib, pylab, e pyplot: como eles estão relacionados?](http://matplotlib.org/faq/usage_faq.html#matplotlib-pyplot-and-pylab-how-are-they-related))

# %% [markdown]
# ### Mode inline do IPython
#
# Dentro do Jupyter Notebook ou do Qtconsole (veja o [Caderno dos shells Python](12-python-shells.ipynb)) podemos usar o comando `%matplotlib inline` para fazer mais gráficos aparecerem dentro de nosso console ou do notebook. Para forçar janelas pop-up em vez disso, use `%matplotlib qt`.
#
# Existe também a mágica `%pylab`, que não só mudará para os gráficos em linha, mas como também executará automaticamente o comando `from pylab import *`. Portanto, seu uso também não é recomendado.

# %% [markdown]
# ### Salvando a figura em um arquivo
#
# Depois de ter criado a figura (usando o comando `plot`) e adicionado quaisquer rótulos, lengendas etc, você tem duas opções para salvar o gráfico.
#
# 1. Você pode exibir a figura (usando `show`) e *interativamente* salvá-lo clicando no ícone do disco.
#
# 2. Você pode (sem exibir a figura) salvá-lo diretamente do seu código Python. O comando a ser usado é o `savefig`. O formato é determinado pela extensão do nome do arquivo fornecido. Aqui está um exemplo (`pylabsavefig.py`) que salva o gráfico mostrado na Figura \[fig:pylab1\]

# %%
import pylab
import numpy as np

x0 =-np.pi
xf = np.pi
n = 1001
x = np.linspace(x0,xf,n)
#x = np.arange(-3.14, 3.14, 0.01)
y = np.sin(x)

pylab.plot(x, y, label='sin(x)')
pylab.savefig('grafico-seno.png')  # salva o arquivo no formato png
pylab.savefig('grafico-seno.eps')  # salva o arquivo no formato eps
pylab.savefig('grafico-seno.pdf')  # salva o arquivo no formato pdf
pylab.savefig('grafico-seno.svg')  # salva o arquivo no formato svg
pylab.show()
pylab.close()

# %%
! ls -alh grafico-seno.*

# %% [markdown]
# Uma nota sobre os formatos de arquivo: Escolha o formato de arquivo `png` se você planeja incluir seu gráfico em um documento do tipo suite de escritório ou em uma página da Web. Escolha o formato de arquivo `eps` ou` pdf` se você pretende incluir a figura em um documento de Latex - dependendo se você deseja compilá-lo usando `latex` (precisa `eps`) ou pdflatex (pode usar `pdf` \[Melhor\] ou `png`). Se a versão da sua suite de escritório (ou outro software de processamento de texto que você usa) puder manipular arquivos `pdf`, é melhor usar `pdf` do que `png`.
#
# Tanto `pdf` como` eps` são formatos de arquivo vetorial, o que significa que é possível ampliar a imagem sem perder a qualidade (as linhas ainda serão nítidas). Os formatos de arquivo como `png` (e `jpg`, `gif`,` tif`, `bmp`) salva a imagem na forma de um bitmap (ou seja, uma matriz de valores de cor) e aparecerá embaçado ou pixelizado ao ampliar (ou quando impresso em alta resolução).

# %% [markdown]
# ### Modo interativo
#
# A Matplotlib pode ser executada em dois modos:
#
# - não-interativo (este é o padrão)
#
# - interativo.
#
# No modo não interativo, nenhum gráfico será exibido até que o comando `show()` tenha sido emitido. Neste modo, o comando `show()` deve ser a última instrução do seu programa.
#
# No modo interativo, as parcelas serão imediatamente exibidas após o comando `plot` ter sido emitido.
#
# É possível alternar o modo interativo usando `pylab.ion()` e desativar usando `pylab.ioff()`. A mágica `%matplotlib` do IPython também permite o modo interativo.

# %% [markdown]
# ### Ajustes finos dos  gráficos
#
# A Matplotlib nos permite ajustar nossos gráficos em inúmeros detalhes. Aqui está um exemplo:

# %%
import pylab
import numpy as np


x0 = -3.14     # Valor inicial de x
xf = +3.14     # Valor final de x
dx = 0.01      # Passo da discretização dx = (xf - x0)/(np-1)

x = np.arange(x0, xf, dx)           # cria um vetor de dados x-data

y1 = np.sin(x)
y2 = np.cos(x)

#Define-se o intervalo de cada eixo
xmin = -3.5   
xmax = +3.5
ymin = -1.1
ymax = +1.1
v = [xmin, xmax, ymin, ymax]                # Vetor que define a escala do gráfico

# Define o tamanho do gráfico
largura = 10  # Largura da figura
altura  =  6  # Altura da figura
pylab.figure(figsize =(largura, altura))     # Define o tamanho do gráfico
# Faz o gráfico das funções
pylab.plot(x, y1, label='sen(x)')
pylab.plot(x, y2, label='cos(x)')
# Altera propriedades do gráfico
pylab.axis(v)                      # Define a escalas x e y do gráfico
pylab.legend()                     # Habilita as legendas
pylab.grid(b='on',axis='both')     # Habilita a grade 
#pylab.grid()                      # Habilita a grade 
pylab.xlabel('x')
pylab.ylabel('y(x)')

pylab.title('Funções seno e cosseno')

# %%
pylab.figure?

# %% [markdown]
# Mostrando alguns outros comandos úteis:
#
# - `figure(figsize =(largura, altura))` define o tamanho de figura para largura x altura em polegadas
#
# - `plot(x, y1, label='sen(x)')` A palavra-chave "label" define o nome da curva que será traçada. O rótulo da linha será mostrado na legenda se o comando `legend()` for usado posteriormente.
#
# - Note que chamar o comando `plot` repetidamente, permite que você sobreponha um número qualquer de curvas.
#
# - `axis([x0, xf, y0, yf])` Isso fixa a área exibida para ir de xmin = x0 a xmax = xf na direção x e de ymin = y0 para ymax = yf na direção y.
#
# - `legend()` Este comando exibirá uma legenda com os rótulos, conforme definido no comando plot. Experimente `help (pylab.legend)` para saber mais sobre o posicionamento da legenda.
#
# - `grid()` Este comando exibirá uma grade no pano de fundo.
#
# - `xlabel ('...')` e `ylabel ('...')` permitem rotular os eixos.
#
# Observe além do que você pode escolher diferentes estilos de linha, espessuras de linha, símbolos e cores para os dados a serem plotados. (A sintaxe é muito semelhante ao MATLAB.) Por exemplo:
#
# - `plot(x, y, 'og')` desenhará círculos (`o`) em verde (`g`)
#
# - `plot (x, y, '- r')` traçará uma linha (`-`) em vermelho (`r`)
#
# - `plot (x, y, '- b', linewidth = 2)` traçará uma linha (`-`) azul (`b`) com espessura de dois pixels `linewidth=2` que é duas vezes maior do que o padrão.
#
# A lista completa de opções pode ser encontrada ao digitar `help(pylab.plot)` no prompt do Python. Como essa documentação é muito útil, repetimos aqui algumas partes:

# %% [markdown]
#     plot(*args, **kwargs)
#         Plot linhas e/ou marcas (sinais) para a
#         :class:`~matplotlib.axes.Axes`.  *args* é uma variável com o comprimento dos
#         argumentos, permitida para multiplos pares *x*, *y* com um formato string
#         opcional. Por exemplo, cada uam das linhas abaixo são permitidas ::
#
#             plot(x, y)         # plot x e y usando o estilo padrão de linha e cor
#             plot(x, y, 'bo')   # plot x e y usando círculos azuis
#             plot(y)            # plot y usando x com sendo os indíces 0..N-1 do array y
#             plot(y, 'r+')      # o mesmo, mas com pulso vermelhos
#
#          Se *x* e/ou *y* forem arrays bidimensionais, então as colunas correspondentes
#          serão usadas para fazer os graficos, ou seja, serão *"plotadas"*.
#
#          Um número arbitrário de grupos *x*, *y*, *fmt* pode ser
#          Especificado, como em ::
#
#              a.plot(x1, y1, 'g^', x2, y2, 'g-')
#
#          Valor de retorno é uma lista de linhas que foram adicionadas.
#
#          Os caracteres da string de formato a seguir são aceitos para
#          O estilo de linha ou marcador:
#
#
#
#         ================    ===============================
#         caracter            descrição
#         ================    ===============================
#         '-'                 estilo de linha sólida
#         '--'                estilo de linha tracejada
#         '-.'                estilo de linha tracejada-pontilhada
#         ':'                 estilo de linha pontilhada
#         '.'                 marcador ponto
#         ','                 marcador pixel
#         'o'                 marcador círculo
#         'v'                 marcador triângulo para baixo
#         '^'                 marcador triângulo para cima
#         '<'                 marcador triângulo para esquerda
#         '>'                 marcador triângulo para direita
#         '1'                 marcador tri_down
#         '2'                 marcador tri_up
#         '3'                 marcador tri_left
#         '4'                 marcador tri_right
#         's'                 marcador quadrado
#         'p'                 marcador pentagono
#         '*'                 marcador estrela
#         'h'                 marcador hexagono1
#         'H'                 marcador hexagono2
#         '+'                 marcador sinal de mais
#         'x'                 marcador x
#         'D'                 marcador diamante
#         'd'                 marcador diamante fino
#         '|'                 marcador vline
#         '_'                 marcador hline
#         ================    ===============================
#
#     As seguintes abreviaturas de cores são suportadas:
#
#     ==========  ========
#     caracter    cor
#     ==========  ========
#     'b'         azul
#     'g'         verde
#     'r'         vermelho
#     'c'         ciano
#     'm'         magenta
#     'y'         amarelo
#     'k'         preto
#     'w'         branco
#     ==========  ========
#
#     Além disso, você pode especificar cores em muitas
#     maneiras diferentes, incluindo nomes completos (``'green'``),
#     strings hexadecimal (`` '# 008000'``), tuplas RGB ou RGBA (`` (0,1,0,1) ``) ou
#     Intensidade de tons de cinza como uma string (`` '0.8'``). Destes, as
#     especificações de string podem ser usadas no lugar de um grupo ``fmt``,
#     mas os formulários de tupla podem ser usados apenas como `` kwargs``.
#
#     Estilos de linhas e cores são combinados em uma única string de formato,
#     como em ``'bo'`` para círculos azuis.
#
#     As *kwargs* podem ser usadas para definir as propriedades das linhas (qualquer
#     propriedade que tenha um método ``set_*``).  Vocẽ pode usar isso para definir
#     um rótulo para a linha (para legendas automáticas), largura de linhas (linewidth),
#     antialising, marcador da cor da face, etc.  Aqui mostramos alguns exemplos::
#
#
#         plot([1,2,3], [1,2,3], 'go-', label='linha 1', linewidth=2)
#         plot([1,2,3], [1,4,9], 'rs',  label='linha 2')
#         axis([0, 4, 0, 10])
#         legend()
#
#     Se você fizer várias linhas com um comando `plot` o kwargs
#     se aplica a todas essas linhas, por exemplo, ::
#
#          plot(x1, y1, x2, y2, antialised=False)
#
#      Nenhuma linha será antialiased.
#
#      Não é necessário usar uma string de formato, as quais são somente
#      abreviaturas. Todas as propriedades da linha podem ser controladas
#      pelos argumentos de palavras-chave. Por exemplo, você pode definir a cor,
#      marcador, linestyle e markercolor com ::
#
#         plot(x, y, color='green', linestyle='dashed', marker='o',
#              markerfacecolor='blue', markersize=12).  See
#              :class:`~matplotlib.lines.Line2D` para maiores detalhes.

# %% [markdown]
# O uso de diferentes estilos de linha e espessuras é particularmente útil quando a cor não pode ser usada para distinguir linhas (por exemplo, quando o gráfico será usado no documento que será impresso apenas em preto e branco).
#
# ### Fazendo o gráfico de mais de uma curva
#
# Há três métodos diferentes para exibir mais de uma curva.
#
# #### Duas (ou mais) curvas em um gráfico
#
# Chamando o comando `plot` repetidamente, mais de uma curva pode ser desenhada no mesmo gráfico. Exemplo:
#
# A localização da legenda pode ser especificada definindo-se loc com uma tupla de 2 floats, que é interpretada como o canto inferior esquerdo da legenda na coordenada de eixos normalizados.
#
# > codes = {'best': 0, 'upper right': 1, 'upper left': 2, 'lower left': 3, 'lower right': 4, 'right': 5, 'center left': 6, 'center right': 7, 'lower center': 8, 'upper center': 9, 'center': 10}

# %%
import numpy as np
t0 = 0
tf = 2*np.pi
dt = 0.01
t = np.arange(t0,tf,dt)

import pylab

largura = 10  # Largura da figura
altura  =  6  # Altura da figura
xmin = -0.5   
xmax = +6.5
ymin = -1.1
ymax = +1.1
v = [xmin, xmax, ymin, ymax]                # Vetor que define a escala do gráfico

pylab.figure(figsize =(largura, altura))     # Define o tamanho do gráfico
# Faz o gráfico das funções
pylab.plot(t,np.sin(t),'--r', label='sen(t)')
pylab.plot(t,np.cos(t),label='cos(t)')              
# Altera propriedades do gráfico
pylab.axis(v)                      # Define a escalas x e y do gráfico
pylab.legend(loc=9)                # Habilita as legendas
pylab.grid(b='on',axis='both')     # Habilita a grade

# %% [markdown]
# #### Dois ou mais gráficos em uma janela ou figura
#
# O comando `pylab.subplot` organiza vários gráfico dentro de uma figura ou janela. A sintaxe geral é
#
#     subplot(numLinhas, numColunas, numGrafico)

# %% [markdown]
# Por exemplo, para organizar 4 gráficos em uma matriz de 2 por 2, e para selecionar o primeiro gráfico para o próximo comando de plotagem, pode-se usar:
#
# ```python
# subplot(2, 2, 1)
# ```

# %% [markdown]
# Aqui mostramos um exemplo completo traçando as curvas das funções seno e cosseno em dois gráficos que estão alinhados um debaixo do outro dentro da mesma janela:

# %%
import numpy as np

t0 = 0
tf = 2*np.pi
dt = 0.01
t = np.arange(t0,tf,dt)

import pylab

largura = 12  # Largura da figura
altura  =  8  # Altura da figura
pylab.figure(figsize =(largura, altura))     # Define o tamanho do gráfico

numLinhas  = 2  # Definimos o númmero de linhas que terá a matriz de gráficos   
numColunas = 2  # Definimos o númmero de colunas que terá a matriz de gráficos 

# Controla a distância entre os eixos verticamente
# hspace controla a distância entre as linhas
# wspace controla a distância entre as colunas
pylab.subplots_adjust(hspace=0.2, wspace=0.4)

# Primeiro gráfico
pylab.subplot(numLinhas, numColunas, 1)
pylab.plot(t, np.sin(t), label='g 1')
pylab.xlabel('t')
pylab.ylabel('sen(t)')
pylab.legend(loc='upper right') # Habilita as legendas

# Segundo gráfico
pylab.subplot(numLinhas, numColunas, 2)
pylab.plot(t, np.cos(t), label='g 2')
pylab.xlabel('t')
pylab.ylabel('cos(t)')
pylab.legend(loc='lower left') # Habilita as legendas

# Terceiro gráfico
pylab.subplot(numLinhas, numColunas, 3)
pylab.plot(t, np.sin(t),'-r', label='g 3')
pylab.xlabel('t')
pylab.ylabel('sen(t)')
pylab.legend(loc='best') # Habilita as legendas

# Quarto gráfico
pylab.subplot(numLinhas, numColunas, 4)
pylab.plot(t, np.cos(t),'-r', label='g 4')
pylab.xlabel('t')
pylab.ylabel('cos(t)')
pylab.legend(loc='upper center') # Habilita as legendas

# %% [markdown]
# ####  Dois ou mais gráficos em uma janela ou figura

# %%
import pylab

largura = 10  # Largura da figura
altura  =  6  # Altura da figura

pylab.figure(1,figsize =(largura, altura))
pylab.plot(range(10),'or')

pylab.figure(2,figsize =(largura, altura))
pylab.plot(range(40),'xb')

# %% [markdown]
# Note que você pode usar `pylab.close()` para fechar uma, algumas ou todas as janelas da figuras (use `help(pylab.close)` para saber mais).

# %% [markdown]
# ## Três gráficos com um único eixo

# %%
"""
Para criar gráficos que compartilham um eixo comum (visualmente), pode-se 
definir o hspace entre os subgráficos perto de zero (não use o zero em si). 
Normalmente você vai querer desligar os rótulos dos eixos em todos eles, 
exceto em um dos eixos. 

Neste exemplo, os gráficos compartilham um xaxis comum, mas você pode seguir 
a mesma lógica para fornecer um eixo y comum.
"""

import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)

s1 = np.sin(2*np.pi*t)
s2 = np.exp(-t)
s3 = s1*s2

# Eixos rect em coords relativas 0,1 à esquerda, fundo, largura, altura. 
# Desativar etiquetas de xtick em todos, exceto na parte inferior

largura = 10  # Largura da figura
altura  = 10  # Altura da figura

f = plt.figure(figsize =(largura, altura)) # Define o tamanho do gráfico
# Controla a distância entre os eixos verticamente
plt.subplots_adjust(hspace=0.001)


ax1 = plt.subplot(311)
ax1.plot(t, s1)
plt.yticks(np.arange(-0.9, 1.0, 0.4))
plt.ylim(-1.05, 1.05)

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(t, s2)
plt.yticks(np.arange(0.1, 1.0, 0.2))
plt.ylim(0, 1)

ax3 = plt.subplot(313, sharex=ax1)
ax3.plot(t, s3)
plt.yticks(np.arange(-0.9, 1.0, 0.4))
plt.ylim(-1, 1)

xticklabels = ax1.get_xticklabels() + ax2.get_xticklabels()
plt.setp(xticklabels, visible=False)

plt.show()

# %% [markdown]
# Use o GridSpec fazer dois gráficos um embaixo do outro sem separação entres eles com
#
# ```python
# gs = gridspec.GridSpec(3, 1)
# gs.update(hspace=0., wspace=0.)
# ax1 = plt.subplot(gs[0:2, 0])
# ax2 = plt.subplot(gs[2, 0], sharex=ax1)
# ```
#
# E isso funciona bem. No entanto, para livra-se dos rótulo superior e inferior de cada subparte, use o seguinte código:
#
# ```python
# nbins = len(ax1.get_yticklabels())
# ax1.yaxis.set_major_locator(MaxNLocator(nbins=nbins, prune='both'))
# nbins = len(ax2.get_yticklabels())
# ax2.yaxis.set_major_locator(MaxNLocator(nbins=nbins, prune='both'))
# ```
# Esse funciona muito bem em alguns casos. Em algumas pedaços, no entanto, pode ocorrer que um ou mais rótulos permaneçam lá. Examinando o manual do Use o GridSpec fazer dois gráficos um embaixo do outro sem separação entres eles com
#
# ```python
# gs = gridspec.GridSpec(3, 1)
# gs.update(hspace=0., wspace=0.)
# ax1 = plt.subplot(gs[0:2, 0])
# ax2 = plt.subplot(gs[2, 0], sharex=ax1)
# ```
#
# E isso funciona bem. No entanto, para livra-se dos rótulo superior e inferior de cada subparte, use o seguinte código:
#
# ```python
# nbins = len(ax1.get_yticklabels())
# ax1.yaxis.set_major_locator(MaxNLocator(nbins=nbins, prune='both'))
# nbins = len(ax2.get_yticklabels())
# ax2.yaxis.set_major_locator(MaxNLocator(nbins=nbins, prune='both'))
# ```
# Esse funciona muito bem em alguns casos. Em algumas pedaços, no entanto, pode ocorrer que um ou mais rótulos permaneçam lá. Examinando o manual do ax1.get_ylim(), verifica-se que pode ocorrer do limite superior, por exemplo, em vez ser 10.0 é na realidade 10.000000000000002, e por essa razão ele não é eliminado. Como isso acontece e como posso me livrar disso?
#
# Aqui está um exemplo: note que na figura o eixo y está invertido e nenhuma etiqueta é podada, mesmo que seja. Observe também que, por algum motivo, o e-label mais baixo é definido como uma posição negativa, que não vejo. As posições y-tick são mostradas nas coordenadas do eixo no texto dentro das parcelas. Na imagem abaixo, o rótulo em 10.6 não deve estar lá!

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator
import numpy as np

x1 = 1
y1 = 1.53839
err1 = 0.00865
x2 = 2
y2 = 0.943045
err2 = 0.00658


t = np.arange(0.0, 3.0, 0.01)

s1 = np.sin(2*np.pi*t)
s2 = np.exp(-t)


plt.clf()
fig = plt.figure(figsize=(8, 8))
gs = gridspec.GridSpec(3, 1)
gs.update(hspace=0., wspace=0.)
ax1 = plt.subplot(gs[0:2, 0])

ax1.errorbar(x1, y1, yerr=err1)
ax1.errorbar(x2, y2, yerr=err2)

ax1.invert_yaxis()

plt.setp(ax1.get_xticklabels(), visible=False)  # Remove x-labels between the plots
ax1.plot(t, s1)
plt.xlim(0, 3)


ax2 = plt.subplot(gs[2, 0], sharex=ax1)
ax2.plot(t, s2)

nbins = len(ax1.get_yticklabels())
ax1.yaxis.set_major_locator(MaxNLocator(nbins=8, prune='both'))
nbins = len(ax2.get_yticklabels())
ax2.yaxis.set_major_locator(MaxNLocator(nbins=6, prune='both'))

#plt.savefig('prune.png')
plt.show()
plt.close()

# %% [markdown]
# Um exemplo uando a numpy

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
def f(x,mu):
    return mu + x**3  # A função é difinida aqui 


# mu é um argumento da função f
# x0 é a condição inicial
# nint é o número de iterações
# retorna 2 vetores apropriados para fazer um gráfico na função cobweb
def cobweb(mu,f,x0,nint):
    x = x0
    xvec = np.zeros(0)
    yvec = np.zeros(0)
    for i in range(nint):
        xvec = np.append(xvec,x)
        y = f(x,mu)
        yvec = np.append(yvec,y)
        xvec = np.append(xvec,y)
        yvec = np.append(yvec,y)
        x = y
        
    return xvec, yvec


xvec, yvec = cobweb(0.43,f,-0.8,10)
print(xvec)
print(yvec)

xv = np.linspace(-1,1.5,151)
yv = f(xv,0.43)

largura = 10  # Largura da figura
altura  = 6  # Altura da figura
plt.figure(figsize =(largura, altura))     

plt.plot(xv,yv,'k-')
plt.plot(xv,xv,'b-')
plt.plot(xvec,yvec,'r-')
plt.show()

# %%
# showing a period 2 orbit
# %matplotlib inline
import matplotlib.pyplot as plt
def f(x,mu):
    return mu*np.sin(np.pi*x) # Aqui define-se a função



# mu é um argumento da função f
# x0 é a condição inicial
# nint é o número de iterações
# retorna 2 vetores apropriados para fazer um gráfico na função cobweb
def cobweb(mu,f,x0,nint):
    x = x0
    xvec = np.zeros(0)
    yvec = np.zeros(0)
    for i in range(nint):
        xvec = np.append(xvec,x)
        y = f(x,mu)
        yvec = np.append(yvec,y)
        xvec = np.append(xvec,y)
        yvec = np.append(yvec,y)
        x = y
        
    return xvec, yvec

mu=0.81
xvec, yvec = cobweb(mu,f,0.3,30)
#print(xvec)
#print(yvec)

xv = np.linspace(0,1.0,101)
yv = f(xv,mu)

largura = 10  # Largura da figura
altura  = 6  # Altura da figura
plt.figure(figsize =(largura, altura)) 

plt.plot(xv,yv,'k-')
plt.plot(xv,xv,'b-')
plt.plot(xvec,yvec,'r-')

# %% [markdown]
# ## Ilustração do teorema de Bolzano
#
# A sua descrição encontra-se em [Teorema do valor intermediário](https://pt.wikipedia.org/wiki/Teorema_do_valor_intermedi%C3%A1rio)  e a [imagem abaixo](https://commons.wikimedia.org/wiki/File:Teorema_de_Bolzano.svg):

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

#canvas
fig = plt.figure(figsize=(5,5), dpi=150, linewidth=0.0, facecolor="white")

# Definição dos eixos
ax = plt.subplot(1,1,1)

ax.set_xlim(-2,10)
ax.set_ylim(-1,5)

ax.set_xticks([])
ax.set_yticks([])

ax.set_frame_on(False)

ax.arrow(-2, 0, 12, 0, head_width=0.15, head_length=0.5, length_includes_head=True)
ax.text(9.5,-0.75,r"$x$",fontsize=14)

ax.arrow(0, -1, 0, 6, head_width=0.25, head_length=0.25, length_includes_head=True)
ax.text(-0.75, 4.5, r"$y$",fontsize=14)

def f(x):
    return 1.5*np.sin(x/1.8) + 2

a = 2
b = 8
x = np.linspace (a, b, 100, endpoint=True)

ax.plot(x, f(x))

# Linhas pontilhadas
# (a, f(a))
ax.plot (a, f(a), 'ko', markersize=3)
ax.text (-1.5, f(a), r"$f(a)$", fontsize=14)
ax.plot ([-0.1, 0.1], [f(a), f(a)], color='black')
ax.plot ([0, a], [f(a), f(a)], color='gray', linestyle='dashed')
ax.plot ([a, a], [f(a), 0], color='gray', linestyle='dashed')
ax.plot ([a, a], [-0.1, 0.1], color='black')
ax.text (a - 0.25, -0.5, r"$a$", fontsize=14)

#(b, f(b))
ax.plot (b, f(b), 'ko', markersize=3)
ax.text (-1.5, f(b), r"$f(b)$", fontsize=14)
ax.plot ([-0.1, 0.1], [f(b), f(b)], color='black')
ax.plot ([0, b], [f(b), f(b)], color='gray', linestyle='dashed')
ax.plot ([b, b], [f(b), 0], color='gray', linestyle='dashed')
ax.plot ([b, b], [-0.1, 0.1], color='black')
ax.text (b - 0.25, -0.5, r"$b$", fontsize=14)


# Linha K
#(c, d = f(p))
c = 2*(a + b)/3
ax.plot (c, f(c), 'ko', markersize=3)
ax.text (-1.5, f(c), r"$d$", fontsize=14)
ax.plot ([-0.1, 0.1], [f(c), f(c)], color='black')
ax.plot ([0, c], [f(c), f(c)], color='red', linestyle='solid')
#ax.plot ([0, b], [f(c), f(c)], color='black', linestyle='dashed')
ax.plot ([c, c], [f(c), 0], color='black', linestyle='dashed')
ax.plot ([c, c], [-0.1, 0.1], color='black')
ax.text (c - 0.25, -0.5, r"$c$", fontsize=14)


plt.show()

fig_file =  "teorema_do_valor_intermediario"
fig.savefig(fig_file+".svg", bbox_inches='tight', pad_inches=0.0)

# %%
# %matplotlib inline
import numpy as np
import scipy as sci
from scipy import optimize
import matplotlib.pyplot as plt

#canvas
fig = plt.figure(figsize=(5,5), dpi=150, linewidth=0.0, facecolor="white")

# Definição dos eixos
ax = plt.subplot(1,1,1)

ax.set_xlim(-2,10)
ax.set_ylim(-5,5)

ax.set_xticks([])
ax.set_yticks([])

ax.set_frame_on(False)

ax.arrow(-2, 0, 12, 0, length_includes_head=True, facecolor='black', head_width=0.2)
ax.text(9.5,-0.75,r"$x$")

ax.arrow(0, -5, 0, 10, length_includes_head=True, facecolor='black', head_width=0.2)
ax.text(-0.75, 4.5, r"$y$")

def fun(x):
    return 3*np.sin(x/1.8)

a = 2
b = 8
x = np.linspace (a, b, 100, endpoint=True)
ax.plot(x, fun(x))

# Linhas pontilhadas
#(a, f(a))
ax.plot (a, fun(a), 'ko', markersize=3)
ax.text (-1.75, fun(a)-0.1, r"$f(a)$")
ax.plot ([-0.1, 0.1], [fun(a), fun(a)], color='black')
ax.plot ([0, a], [fun(a), fun(a)], color='gray', linestyle='dashed')
ax.plot ([a, a], [fun(a), 0], color='gray', linestyle='dashed')
ax.plot ([a, a], [-0.1, 0.1], color='black')
ax.text (a - 0.25, -0.75, r"$a$")

#(b, f(b))
ax.plot (b, fun(b), 'ko', markersize=3)
ax.text (-1.75, fun(b)-0.1, r"$f(b)$")
ax.plot ([-0.1, 0.1], [fun(b), fun(b)], color='black')
ax.plot ([0, b], [fun(b), fun(b)], color='gray', linestyle='dashed')
ax.plot ([b, b], [fun(b), 0], color='gray', linestyle='dashed')
ax.plot ([b, b], [-0.1, 0.1], color='black')
ax.text (b - 0.25, 0.25, r"$b$")


#f(p) = 0
p = sci.optimize.fsolve(fun,(a+b)/2)
ax.plot (p, fun(p), 'ko', markersize=3, markerfacecolor='red')
ax.text (p-0.35, -0.75, r"$c$")


fig_file =  "teorema_de_Bolzano"
fig.savefig(fig_file+".svg", bbox_inches='tight')
plt.show() # mostra a figura no notebook

# %% [markdown]
# ## Legendas e LaTeX

# %%
"""
Gráfico demonstrando a integral como a área sob uma curva.

Embora este seja um exemplo simples, ele demonstra alguns ajustes importantes:

     * Um gráfico de linha simples com cor personalizada e largura de linha.
     * Uma região sombreada criada usando um Polygon patch.
     * Uma etiqueta de texto com renderização mathtext.
     * chamada figtext para rotular os eixos x e y.
     * Uso dos spines do eixo para ocultar as espinhas superior e direita.
     * Personalizando a colocação dos ticks e rótulos.
"""
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon


def func(x):
    return (x - 3) * (x - 5) * (x - 7) + 85


a, b = 2, 9  # Limites da integral
x = np.linspace(0, 10)
y = func(x)


largura = 10  # Largura da figura
altura  = 6  # Altura da figura
#
fig, ax = plt.subplots(figsize =(largura, altura))
#
plt.plot(x, y, 'r', linewidth=2)
plt.ylim(ymin=0)

# Tornar a região sombreada
ix = np.linspace(a, b)
iy = func(ix)
verts = [(a, 0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
ax.add_patch(poly)

plt.text(0.5 * (a + b), 30, r"$\int_a^b f(x)\mathrm{d}x$",
         horizontalalignment='center', fontsize=20)

plt.figtext(0.9, 0.05, '$x$')
plt.figtext(0.1, 0.9, '$y$')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])

plt.show()

# %%
"""
===============================
Legendas usando rótulos pré-definidos
===============================

Observe como as legendas são definidas com gráficosa!
"""


import numpy as np
import matplotlib.pyplot as plt


# Criando alguns dados
a = b = np.arange(0, 3, .02)
c = np.exp(a)
d = c[::-1]

largura = 10  # Largura da figura
altura  = 6  # Altura da figura

# Crie gráficos com etiquetas pré-definidas.
fig, ax = plt.subplots(figsize =(largura, altura))
ax.plot(a, c, 'k--',   label='Comprimento do Modelo')
ax.plot(a, d, 'k:',    label='Comprimento dos Dados')
ax.plot(a, c + d, 'k', label='Comprimento total da mensagem')


legend = ax.legend(loc='upper center', shadow=True, fontsize='x-large')

# Coloque uma cor de fundo mais agradável na legenda.
legend.get_frame().set_facecolor('#00FFCC')

plt.show()

# %%
# Faça uma legenda para linhas específicas.
import matplotlib.pyplot as plt
import numpy as np


t1 = np.arange(0.0, 2.0, 0.1)
t2 = np.arange(0.0, 2.0, 0.01)

# Note que plot retorna uma lista de linhas. O uso de "l1, = plot" 
# extrai o primeiro elemento da lista em l1 usando descompactar tuplas. 
# Então l1 é uma instância de Line2D, não uma sequência de linhas

largura = 10  # Largura da figura
altura  =  6  # Altura da figura
plt.figure(figsize =(largura, altura))     # Define o tamanho do gráfico

l1, = plt.plot(t2, np.exp(-t2),lw=5)
l2, l3 = plt.plot(t2, np.sin(2 * np.pi * t2), '--o', t1, np.log(1 + t1), '.')
l4, = plt.plot(t2, np.exp(-t2) * np.sin(2 * np.pi * t2), 's-.')

plt.legend((l2, l4), ('oscilatório', 'amortecido'), loc='upper right', shadow=True)
plt.xlabel('tempo')
plt.ylabel('volts')
plt.title('Oscilação amortecida')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(-1, 2, .01)
s = np.sin(2*np.pi*t)

largura = 10  # Largura da figura
altura  =  6  # Altura da figura
plt.figure(figsize =(largura, altura))     # Define o tamanho do gráfico

plt.plot(t, s)
# Desenha uma hline espessa e vermelha em y = 0 que abrange o xrange
l = plt.axhline(linewidth=8, color='#d62728')

# Desenha uma hline padrão em y = 1 que abrange o xrange
l = plt.axhline(y=1)

# Desenha uma vline padrão em x = 1 que abrange o yrange
l = plt.axvline(x=1)

# Desenha uma vline espessa e azul em x = 0 que abrange o quadrante 
# superior do yrange
l = plt.axvline(x=0, ymin=0.75, linewidth=8, color='#1f77b4')

# Desenha uma hline padrão em y = 0,5 que abrange o meio da metade dos eixos
l = plt.axhline(y=.5, xmin=0.25, xmax=0.75)
 
p = plt.axhspan(0.25, 0.75, facecolor='0.5', alpha=0.4) # cinza horizontal

p = plt.axvspan(1.25, 1.55, facecolor='#2ca02c', alpha=0.5) # verder vertical

plt.axis([-1, 2, -1, 2])


plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import pi, sin, linspace, interp
#from matplotlib.mlab import stineman_interp
# veja https://matplotlib.org/3.1.1/api/api_changes.html#removals

x = linspace(0, 2*pi, 20)
y = sin(x)
yp = None
xi = linspace(x[0], x[-1], 100)
yi = interp(xi, x, y, yp)

largura = 10  # Largura da figura
altura  =  6  # Altura da figura

fig, ax = plt.subplots(figsize =(largura, altura))
ax.plot(x, y, 'o', xi, yi, '.')
plt.show()

# %% [markdown]
# ## Coordenadas polares

# %%
"""
Demonstração de um gráfico em coordenadas polares.
"""
import numpy as np
import matplotlib.pyplot as plt


r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

largura = 8  # Largura da figura
altura  = 8  # Altura da figura
fig, ax = plt.subplots(figsize =(largura, altura)) # Define tamanho da imagem

ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # menos ticks radiais
ax.set_rlabel_position(-22.5)    # Obtém rótulos radiais longe da linha traçada
ax.grid(True)

ax.set_title("Um gráfico de linha em um eixo polar", va='bottom')
plt.show()

# %%
# %matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)

plt.show()

# %%
import numpy as np
from matplotlib.pyplot import figure, show, rc

# radar green, linhas sólidas da grade 
rc('grid', color='#316931', linewidth=1, linestyle='-')
rc('xtick', labelsize=15)
rc('ytick', labelsize=15)

# Força figura quadrada e eixos quadrados parece melhor para polar, IMO
fig = figure(figsize=(8, 8))
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8],
                  projection='polar', facecolor='#d5de9c')

r = np.arange(0, 3.0, 0.01)
theta = 2*np.pi*r
ax.plot(theta, r, color='#ee8d18', lw=3, label='a line')
ax.plot(0.5*theta, r, color='blue', ls='--', lw=3, label='another line')
ax.legend()

show()

# %% [markdown]
# ## Dipolo elétrico

# %%
"""
Demonstra o cáculo do gradiente com a matplotlib.tri.CubicTriInterpolator.
"""
from matplotlib.tri import Triangulation, UniformTriRefiner,\
    CubicTriInterpolator
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import math


#-----------------------------------------------------------------------------
# Potencial elétrico de um dipolo
#-----------------------------------------------------------------------------
def dipole_potential(x, y):
    """ The electric dipole potential V """
    r_sq = x**2 + y**2
    theta = np.arctan2(y, x)
    z = np.cos(theta)/r_sq
    return (np.max(z) - z) / (np.max(z) - np.min(z))


#-----------------------------------------------------------------------------
# Criando uma triangulação
#-----------------------------------------------------------------------------
# Primeiro crie as coordenadas x e y dos pontos.
n_angles = 30
n_radii = 10
min_radius = 0.2
radii = np.linspace(min_radius, 0.95, n_radii)

angles = np.linspace(0, 2*math.pi, n_angles, endpoint=False)
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)
angles[:, 1::2] += math.pi/n_angles

x = (radii*np.cos(angles)).flatten()
y = (radii*np.sin(angles)).flatten()
V = dipole_potential(x, y)

# Criar a Triangulação; Sem triângulos especificados para a 
# triangulação Delaunay criado
triang = Triangulation(x, y)

# Mascara fora de triângulos indesejados.
xmid = x[triang.triangles].mean(axis=1)
ymid = y[triang.triangles].mean(axis=1)
mask = np.where(xmid*xmid + ymid*ymid < min_radius*min_radius, 1, 0)
triang.set_mask(mask)

#-----------------------------------------------------------------------------
# Refinar dados - interpola o potencial elétrico V
#-----------------------------------------------------------------------------
refiner = UniformTriRefiner(triang)
tri_refi, z_test_refi = refiner.refine_field(V, subdiv=3)

#-----------------------------------------------------------------------------
# Calcula o campo elétrico (Ex, Ey) como gradiente de potencial elétrico
#-----------------------------------------------------------------------------
tci = CubicTriInterpolator(triang, -V)
# Gradiente solicitado aqui nos nós do mesh, mas poderia ser em qualquer outro lugar:
(Ex, Ey) = tci.gradient(triang.x, triang.y)
E_norm = np.sqrt(Ex**2 + Ey**2)

#-----------------------------------------------------------------------------
# Faz o gráfico da triangulação, o potencial iso-contornos e o campo vetorial
#-----------------------------------------------------------------------------

largura = 10  # Largura da figura
altura  = 10  # Altura da figura
#plt.figure(figsize =(largura, altura))     # Define o tamanho do gráfico

fig, ax = plt.subplots(figsize =(largura, altura))
ax.set_aspect('equal')
# Aplicar as margens e ampliá elas para dar espaço aos vetores.
ax.use_sticky_edges = False
ax.margins(0.07)

ax.triplot(triang, color='0.8')

levels = np.arange(0., 1., 0.01)
cmap = cm.get_cmap(name='hot', lut=None)
ax.tricontour(tri_refi, z_test_refi, levels=levels, cmap=cmap,
              linewidths=[2.0, 1.0, 1.0, 1.0])
# Faz um gráfico da direção do vetor campo elétrico 
ax.quiver(triang.x, triang.y, Ex/E_norm, Ey/E_norm,
          units='xy', scale=10., zorder=3, color='blue',
          width=0.007, headwidth=3., headlength=4.)

ax.set_title('Gráfico do gradiente: um dipolo elétrico')


plt.show()

# %% [markdown]
# ### Histogramas
#
# <embed src="code/pylab/pylabhistogram.pdf" style="width:100.0%" />
#
# O programa abaixo demonstra como criar histogramas de dados estatísticos na Matplotlib. O gráfico resultante é mostrado na figura

# %%
# Versão modificada do original encontrado em
# http://matplotlib.sourceforge.net/plot_directive/mpl_examples/...
#                                 /pylab_examples/histogram_demo.py
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6), dpi=300, linewidth=0.0, facecolor="yellow")

# cria os dados a serem tratados
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000) # Cria-se um vetor aleatório com 10000 pontos

# histograma dos dados
n, bins, patches = plt.hist(x, 60, normed=1,
                            facecolor='green', alpha=0.85)

# Alguns ajuste finos no gráfico 
plt.xlabel('Esperteza')
plt.ylabel('Probabilidade')
#Pode-se usar strings Latex para os rótulos e títulos:
plt.title(r'$\mathrm{Histograma\ do\ QI:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)


# adiciona uma linha contendo o "melhor ajuste" ao histograma
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1.5)

#salva a figura em um arquivo pdf, mas poderia ser:svg,eps,png,jpg, etc
plt.savefig('pylab-histograma.pdf')

# %%
? np.random.random

# %% [markdown]
# **Não tente entender todos os comandos neste arquivo:** alguns são bastante especializados e não foram abordados neste texto. A intenção é fornecer alguns exemplos para mostrar o que pode - em princípio - ser feito com a Matplotlib. Se você precisa de um gráfico como este, a expectativa é que você precisará experimentar e possivelmente aprender um pouco mais sobre a Matplotlib, para fazer o seu gráfico. Entretanto você já terá um bom ponto de partida.

# %%
"""
========================================
Método de folha de estilos Bayesian para Hackers
========================================

Este exemplo demonstra o estilo usado no "Bayesian Methods for Hackers" 
[1]_ livro on-line.

.. [1] http://camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/

"""
from numpy.random import beta
import matplotlib.pyplot as plt


plt.style.use('bmh')


def plot_beta_hist(ax, a, b):
    ax.hist(beta(a, b, size=10000), histtype="stepfilled",
            bins=40, alpha=0.8, normed=True)

largura = 10  # Largura da figura
altura  = 6  # Altura da figura
#plt.figure(figsize =(largura, altura))     # Define o tamanho do gráfico

fig, ax = plt.subplots(figsize =(largura, altura)) # Define o tamanho do gráfico

plot_beta_hist(ax, 10, 10)
plot_beta_hist(ax, 4, 12)
plot_beta_hist(ax, 50, 12)
plot_beta_hist(ax, 6, 55)
ax.set_title("Folha de estilo 'bmh'")

plt.show()

# %% [markdown]
# ## Função integral do cosseno e seno
#
# Esse exemplo de [integrais trigonométicas](https://en.wikipedia.org/wiki/Trigonometric_integral). Essa função é definida por
#
# $$\operatorname{Ci}(x) = -\int_x^\infty \frac{\cos t}{t}\,dt = \gamma + \ln x + \int_0^x \frac{\cos t - 1}{t}\,dt
# \qquad (|{\rm Arg}(x)|<\pi)$$
#
#
# Consulte a biblioteca da sipy para [funções especiais](https://docs.scipy.org/doc/scipy/reference/special.html)
#
#
# [integral do cosseno](https://commons.wikimedia.org/wiki/File:Cosine_integral.svg)
#
#
# A localização da legenda pode ser especificada definindo-se loc com uma tupla de 2 floats, que é interpretada como o canto inferior esquerdo da legenda na coordenada de eixos normalizados.
#
# > codes = {'best': 0, 'upper right': 1, 'upper left': 2, 'lower left': 3, 'lower right': 4, 'right': 5, 'center left': 6, 'center right': 7, 'lower center': 8, 'upper center': 9, 'center': 10}

# %%
# %matplotlib inline
from numpy import *
from scipy.special import sici
from matplotlib.pyplot import *

# Calculando o valor das funções
x = linspace(0.001, 25, 100)   # definino o vetor x
(y_sine,y_cosine) = sici(x);   # Calcula o valor das funções SI(x) e CI(x)


# Defini a Matriz Nlinhas x Ncolunas que será mostrado os gráficos
Nlinhas, Ncolunas = 1, 2  

largura = 14  # Largura da figura
altura  = 6  # Altura da figura

fig = figure(figsize=(largura, altura)) # Define o tamanho do gráfico


# Integral do seno
ax = fig.add_subplot(Nlinhas,Ncolunas,1) # Primeiro gráfico da Matriz Nlinhas x Ncolunas
ax.set_ylim(0, 2)
# Aqui fazemos uso do LaTeX para expressar a legenda da figura
ax.plot(x,y_sine, linewidth=2, label=r"Si$(x)=\int_0^x\frac{\sin(t)}{t}dt$")
ax.plot([0, 25], [1.58, 1.58], linestyle='--', color='g', label=r"asymptote");
ax.set_ylabel(r"Si($x$)")
ax.set_xlabel(r"$x$")
ax.grid(True)
ax.minorticks_on()
legend(loc=4)
fig.savefig("Sine integral.svg",bbox_inches="tight",\
        pad_inches=.15)


# Integral do cosseno
ax = fig.add_subplot(Nlinhas,Ncolunas,2) # Segundo gráfico da Matriz Nlinhas x Ncolunas
ax.set_ylim(-6.5, 0.75)
# Aqui fazemos uso do LaTeX para expressar a legenda da figura
ax.plot(x,y_cosine, linewidth=2, label=r"Ci$(x)=\gamma+\ln(x)+\int_0^x\frac{\cos(t)-1}{t}dt$")
ax.plot([0, 25], [0, 0], linestyle='--', color='g', label=r"asymptote");
ax.set_ylabel(r"Ci($x$)")
ax.set_xlabel(r"$x$")
ax.grid(True)
ax.minorticks_on()
fig.savefig("Cosine integral.svg",bbox_inches="tight",\
        pad_inches=.15)
legend(loc=4)
show()

# %%
# %matplotlib inline
from numpy import *
from scipy.special import sici
from matplotlib.pyplot import *
 
fig = figure(figsize=(8,6))
ax = fig.add_subplot(111)
x = linspace(0.001, 25, 100)
(y_sine,y_cosine) = sici(x);
ax.set_ylim(0, 2)
# Aqui fazemos uso do LaTeX para expressar a legenda da figura
ax.plot(x,y_sine, linewidth=2, label=r"Si$(x)=\int_0^x\frac{\sin(t)}{t}dt$")
ax.plot([0, 25], [1.58, 1.58], linestyle='--', color='g', label=r"asymptote");
ax.set_ylabel(r"Si($x$)")
ax.set_xlabel(r"$x$")
ax.grid(True)
ax.minorticks_on()
fig.savefig("Sine integral.svg",bbox_inches="tight",\
        pad_inches=.15)
legend(loc=4)
show()

# %% [markdown]
# ## Curvas Preenchidas

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2*np.pi*x)
y2 = 1.2*np.sin(4*np.pi*x)

largura = 10  # Largura da figura
altura  = 10  # Altura da figura

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True,figsize =(largura, altura))
# Controlando a distância entre os eixos
plt.subplots_adjust(hspace=0.001)

ax1.fill_between(x, 0, y1)
ax1.set_ylabel('between y1 and 0')

ax2.fill_between(x, y1, 1)
ax2.set_ylabel('between y1 and 1')

ax3.fill_between(x, y1, y2)
ax3.set_ylabel('between y1 and y2')
ax3.set_xlabel('x')

# Agora preencha a região entre y1 e y2 a qual uma condição lógica é satisfeita. 
# Observe que isso é diferente de chamar "fill_between(x [where], y1 [where], y2 [where]" 
# devido aos efeitos de borda em várias regiões contínuas.

fig, (ax, ax1) = plt.subplots(2, 1, sharex=True, figsize =(largura, altura))
ax.plot(x, y1, x, y2, color='black')
ax.fill_between(x, y1, y2, where=y2 >= y1, facecolor='green', interpolate=True)
ax.fill_between(x, y1, y2, where=y2 <= y1, facecolor='red', interpolate=True)
ax.set_title('fill between where')

# Suporte de teste para matrizes mascaradas.
y2 = np.ma.masked_greater(y2, 1.0)
ax1.plot(x, y1, x, y2, color='black')
ax1.fill_between(x, y1, y2, where=y2 >= y1, facecolor='green', interpolate=True)
ax1.fill_between(x, y1, y2, where=y2 <= y1, facecolor='red', interpolate=True)
ax1.set_title('Now regions with y2>1 are masked')

# Este exemplo ilustra um problema; Devido à grade de dados, existem triângulos 
# não preenchidos indesejados nos pontos de cruzamento. Uma solução de força bruta 
# seria interpolar todas as matrizes para uma grade muito fina antes de plotar.

# Mostram como usar transformações para criar eixos de spans onde uma determinada 
# condição é satisfeita

largura = 10  # Largura da figura
altura  = 6  # Altura da figura

fig, ax = plt.subplots(figsize =(largura, altura))
y = np.sin(4*np.pi*x)
ax.plot(x, y, color='black')

# Use as coordenadas de dados para o eixo x e as coordenadas dos eixos para o eixo y
import matplotlib.transforms as mtransforms
trans = mtransforms.blended_transform_factory(ax.transData, ax.transAxes)
theta = 0.9
ax.axhline(theta, color='green', lw=2, alpha=0.5)
ax.axhline(-theta, color='red', lw=2, alpha=0.5)
ax.fill_between(x, 0, 1, where=y >  theta, facecolor='green', alpha=0.5, transform=trans)
ax.fill_between(x, 0, 1, where=y < -theta, facecolor='red',   alpha=0.5, transform=trans)


plt.show()

# %% [markdown]
# ## Linhas multicoloridas

# %%
'''
Partes de uma linha colorida com base nas suas propriedades, por exemplo, inclinação.
'''

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm

x = np.linspace(0, 3 * np.pi, 500)
y = np.sin(x)
z = np.cos(0.5 * (x[:-1] + x[1:]))  # first derivative

# Cria um mapa de cores para vermelho, verde e azul e uma norma para colorir
# f' < -0.5 red, f' > 0.5 blue, e o resto green
cmap = ListedColormap(['r', 'g', 'b'])
norm = BoundaryNorm([-1, -0.5, 0.5, 1], cmap.N)

# Criar um conjunto de segmentos de linha para que possamos colori-los individualmente 
# Isso cria os pontos como uma matriz N x 1 x 2 para que possamos empilhar pontos 
# facilmente para obter os segmentos. A matriz de segmentos para a coleção de linhas 
# precisa ser numlines x point por linha x 2 (x e y)
points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

# Crie o objeto de coleção de linha, definindo os parâmetros de mapeamento de cores.
# Tem de definir os valores reais utilizados para o mapeamento de cores separadamente.
lc = LineCollection(segments, cmap=cmap, norm=norm)
lc.set_array(z)
lc.set_linewidth(3)

# Tamanho das figuras
largura = 10  # Largura da figura
altura  = 6  # Altura da figura

fig1 = plt.figure(figsize =(largura, altura))
plt.gca().add_collection(lc)
plt.xlim(x.min(), x.max())
plt.ylim(-1.1, 1.1)

# Agora, faça um segundo gráfico colorindo a curva usando um mapa de cores contínuo
t = np.linspace(0, 10, 200)
x = np.cos(np.pi * t)
y = np.sin(t)
points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

lc = LineCollection(segments, cmap=plt.get_cmap('copper'),
                    norm=plt.Normalize(0, 10))
lc.set_array(t)
lc.set_linewidth(3)

fig2 = plt.figure(figsize =(largura, altura))
plt.gca().add_collection(lc)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.show()

# %%
"""
Algumas pessoas preferem escrever um código mais pythonic, 
orientado a objeto em vez de usar a interface pyplot para 
matplotlib. Este exemplo mostra como.

A menos que você seja um desenvolvedor de aplicativos, 
recomenda-se usar parte da interface pyplot, particularmente 
os comandos figure, close, subplot, axes, e show. Estes 
escondem muita complexidade de código que não é necessário 
conhecer na criação de figuras típicas, como instanciar as 
instâncias de DPI, gerenciar as caixas delimitadoras dos 
elementos da figura, criar e realizar janelas de GUI e 
incorporar figuras nelas.


Se você é um desenvolvedor de aplicativos e deseja incorporar a 
matplotlib no seu aplicativo, siga o exemplo de examples/embedding_in_wx.py, 
examples/embedding_in_gtk.py ou examples/embedding_in_tk.py. Neste caso, 
você vai querer controlar a criação de todas as suas figuras, 
incorporá-las em janelas de aplicativos, etc.

Se você é um desenvolvedor de aplicativos da Web, talvez queira usar 
o exemplo em webapp_demo.py, que mostra como usar o canvas backgag agg 
figura diretamente, sem nenhum dos globais (current figure, current axes) 
que estão presentes na interface pyplot. Observe que não há nenhuma 
razão pela qual a interface pyplot não funcionará para desenvolvedores 
de aplicativos da web, no entanto.

Se você ver um exemplo no diretório de exemplos escrito na interface pyplot, 
e você quiser emular isso usando as chamadas verdadeiras dos método python, 
há um mapeamento fácil. Muitos desses exemplos usam 'set' para controlar as 
propriedades da figura. Veja como mapear esses comandos em métodos de instância

A sintaxe do conjunto é
  plt.setp(object or sequence, somestring, attribute)


se chamado com um objeto, set chama
  object.set_somestring(attribute)

se chamado com uma seqüência, set faz

  for object in sequence:
       object.set_somestring(attribute)

Assim, para o exemplo, se a é o objeto dos eixos, pode-se fazer

  a.set_xticklabels([])
  a.set_yticklabels([])
  a.set_xticks([])
  a.set_yticks([])
"""


from matplotlib.pyplot import figure, show
from numpy import arange, sin, pi

t = arange(0.0, 1.0, 0.01)

fig = figure(1,figsize=(10,6))
# Controlando a distância entre os eixos
plt.subplots_adjust(hspace=0.001)

ax1 = fig.add_subplot(211)
ax1.plot(t, sin(2*pi*t))
ax1.grid(True)
ax1.set_ylim((-2, 2))
ax1.set_ylabel('Amplitude')
ax1.set_title('Uma onda senoidal ou duas')

for label in ax1.get_xticklabels():
    label.set_color('r')


ax2 = fig.add_subplot(212)
ax2.plot(t, sin(2*2*pi*t))
ax2.grid(True)
ax2.set_ylim((-2, 2))
l = ax2.set_xlabel('Frequência (Hz)')
l.set_color('g')
l.set_fontsize('large')

show()

# %%
"""
===================
Estilos com o cycler
===================

Demonstração de configurações personalizadas de ciclo de 
propriedade para controlar cores e outras propriedades de 
estilo para gráficos de várias linhas.

Este exemplo demonstra duas APIs diferentes:

     1. Definindo o parâmetro rc padrão especificando o ciclo 
        de propriedade. Isso afeta todos os eixos subseqüentes 
        (mas não os eixos já criados).

     2. Definir o ciclo de propriedades para um único par de eixos.

"""
from cycler import cycler
import numpy as np
import matplotlib.pyplot as plt

# Tamanho das figuras
largura = 10  # Largura da figura
altura  = 6  # Altura da figura

x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2*np.pi, 4, endpoint=False)
# Criar matriz com curva de seno-deslocada ao longo de cada coluna
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# 1. Definindo o ciclo de prop no parâmetro rc padrão
plt.rc('lines', linewidth=4)
plt.rc('axes', prop_cycle=(cycler('color', ['r', 'g', 'b', 'y']) +
                           cycler('linestyle', ['-', '--', ':', '-.'])))
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize =(largura, altura))
ax0.plot(yy)
ax0.set_title('Definir o ciclo de cores padrão para rgby')

# 2. Definir ciclo de suporte para um único conjunto de eixos
ax1.set_prop_cycle(cycler('color', ['c', 'm', 'y', 'k']) +
                   cycler('lw', [1, 2, 3, 4]))
ax1.plot(yy)
ax1.set_title('Definir o ciclo de cores dos eixos para cmyk')

# Ajustar o espaçamento entre os subplots para evitar que as 
# legendas se sobreponham
fig.subplots_adjust(hspace=0.3)
plt.show()

# %%
# %matplotlib inline

# %%
# http://matplotlib.org/examples/pylab_examples/axes_demo.html
import matplotlib.pyplot as plt
import numpy as np

# cria um conjunto de dados para fazer os gráficos
dt = 0.001
t = np.arange(0.0, 10.0, dt)
r = np.exp(-t[:1000]/0.05)               # Resposta por impulsos
x = np.random.randn(len(t))
s = np.convolve(x, r)[:len(x)]*dt        # Ruído colorido

# Tamanho das figuras
largura = 10  # Largura da figura
altura  = 6  # Altura da figura
plt.figure(figsize =(largura, altura))

# O eixo principal é o do subplot(111) por padrão
plt.plot(t, s)
plt.axis([0, 1, 1.1*np.amin(s), 2*np.amax(s)])
plt.xlabel('tempo (s)')
plt.ylabel('corrente (nA)')
plt.title('Ruído Gaussiano colorido')
plt.xlim(0, 1.0)
#plt.ylim(-0.01, 0.03)

# Este é um "inset" sobre o gráfico original
a = plt.axes([.65, .6, .2, .2], facecolor='y')
n, bins, patches = plt.hist(s, 400, normed=1)
plt.title('Probability')
plt.xticks([])
plt.yticks([])

x0 = 0.2  # Posição horizontal do centro do gráfico percentual em relação ao gráfico
y0 = 0.55  # Posição vertical do centro do gráfico percentula em relação ao gráfico
lg = 0.2  # Largura da figura percentual em relação ao gráfico
al = 0.2  # Altura da figura  percentual em relação ao gráfico

# Esse é o outro "inset" sobre o gráfico original
a = plt.axes([x0, y0, lg, al], facecolor='y')
plt.plot(t[:len(r)], r)
plt.title('Resposta por impulsos')
plt.xlim(0, 0.2)
#plt.ylim(0, 0.03)
plt.xticks([])
plt.yticks([])

plt.show()

# %%
# %matplolib notbook

# %% [markdown]
# ## Campos vetoriais

# %%
'''
Demonstração das funções quiver e quiverkey. Esta é a utilização 
da nova versão do código em quiver.py.

Problema conhecido: o plot autoscaling não leva em conta as setas, 
de modo que aqueles nos limites muitas vezes estão fora da imagem. 
Este *não* é um problema fácil de resolver de uma maneira geral. 
A solução alternativa é expandir manualmente os eixos.

'''
import matplotlib.pyplot as plt
import numpy as np
from numpy import ma

X, Y = np.meshgrid(np.arange(0, 2 * np.pi, .2), np.arange(0, 2 * np.pi, .2))
U = np.cos(X)
V = np.sin(Y)

# Figura 1
plt.figure(1,figsize=(10,6))
Q  = plt.quiver(U, V)
qk = plt.quiverkey(Q, 0.5, 0.98, 2, r'$2 \frac{m}{s}$', labelpos='W',
                   fontproperties={'weight': 'bold'})
l, r, b, t = plt.axis()
dx, dy = r - l, t - b
plt.axis([l - 0.05*dx, r + 0.05*dx, b - 0.05*dy, t + 0.05*dy])

plt.title('Argumentos mínimos, sem os kwargs')

# Figura 2
plt.figure(2,figsize=(10,6))
Q = plt.quiver(X, Y, U, V, units='width')
qk = plt.quiverkey(Q, 0.9, 0.95, 2, r'$2 \frac{m}{s}$',
                   labelpos='E',
                   coordinates='figure',
                   fontproperties={'weight': 'bold'})
plt.axis([-1, 7, -1, 7])
plt.title('Escalas com a largura do grafico, não vista')

# Figura 3
plt.figure(3,figsize=(10,6))
Q = plt.quiver(X[::3, ::3], Y[::3, ::3], U[::3, ::3], V[::3, ::3],
               pivot='mid', color='r', units='inches')
qk = plt.quiverkey(Q, 0.5, 0.03, 1, r'$1 \frac{m}{s}$',
                   fontproperties={'weight': 'bold'})
plt.plot(X[::3, ::3], Y[::3, ::3], 'k.')
plt.axis([-1, 7, -1, 7])
plt.title("pivot='mid'; cada terceira seta; units='inches'")

# Figura 4
plt.figure(4,figsize=(10,6))
M = np.hypot(U, V)
Q = plt.quiver(X, Y, U, V, M,
               units='x',
               pivot='tip',
               width=0.022,
               scale=1 / 0.15)
qk = plt.quiverkey(Q, 0.9, 1.05, 1, r'$1 \frac{m}{s}$',
                   labelpos='E',
                   fontproperties={'weight': 'bold'})
plt.plot(X, Y, 'k.', markersize=2)
plt.axis([-1, 7, -1, 7])
plt.title("Escalas com vista x; pivot='tip'")

# Figura 5
plt.figure(5,figsize=(10,6))
Q = plt.quiver(X[::3, ::3], Y[::3, ::3], U[::3, ::3], V[::3, ::3],
               color='r', units='x',
               linewidths=(0.5,), edgecolors=('k'), headaxislength=5)
qk = plt.quiverkey(Q, 0.5, 0.03, 1, r'$1 \frac{m}{s}$',
                   fontproperties={'weight': 'bold'})
plt.axis([-1, 7, -1, 7])
plt.title("Cabeça triangular; escalas com vista x; bordas pretas")

# Figura 6
plt.figure(6,figsize=(10,6))
M = np.zeros(U.shape, dtype='bool')
XMaskStart = U.shape[0]//3
YMaskStart = U.shape[1]//3
XMaskStop = 2*U.shape[0]//3
YMaskStop = 2*U.shape[1]//3

M[XMaskStart:XMaskStop,
  YMaskStart:YMaskStop] = True
U = ma.masked_array(U, mask=M)
V = ma.masked_array(V, mask=M)
Q = plt.quiver(U, V)
qk = plt.quiverkey(Q, 0.5, 0.98, 2, r'$2 \frac{m}{s}$', labelpos='W',
                   fontproperties={'weight': 'bold'})
l, r, b, t = plt.axis()
dx, dy = r - l, t - b
plt.axis([l - 0.05 * dx, r + 0.05 * dx, b - 0.05 * dy, t + 0.05 * dy])
plt.title('Argumentos mínimos, sem os kwargs - valores mascarados')


plt.show()

# %% [markdown]
# ## Equação de Van der Pol
#
#
# Esse exemplo, foi extraído da página [Equação de Van der Pol](https://pt.wikipedia.org/wiki/Equa%C3%A7%C3%A3o_de_Van_der_Pol).
#
# Esse é um exemplo de solução numérica do oscilador de Van der Pol, com $\mu = 5$.  O intervalo de tempo entre cada círculo é o mesmo e suas cores são proporcionais a velocidade do oscilador no instante de tempo que representam. Círculos vermelhos possuem velocidades maiores que 0.25 vezes a velocidade máxima, círculos azuis possuem velocidades menores que 0.25 vezes a velocidade minima e círculos verdes possuem velocidades entre esses valores.
# A '''equação de Van der Pol''' representa um [Vibração|oscilador] com um termo de amortecimento [Sistema dinâmico não linear|não linear]. Sua evolução no tempo é descrita pela [equação diferencial] de segunda ordem:
#
# $$\frac{dx^2}{dt} - \mu(1-x^2)\frac{dx}{dt} + x = 0$$
#
# onde $x(t)$  é a posição do oscilador e $\mu$ mede a força do termo de amortecimento. No caso especial $\mu = 0$ recuperamos um [oscilador harmônico] simples.
#
# ### História
#
# O oscilador de Van der Pol foi proposto em 1920 por [Balthasar van der Pol].

# %%
# %matplotlib inline
from numpy import *
from scipy import *
from scipy.integrate import odeint
from matplotlib.pyplot import *
from mpl_toolkits.axes_grid.axislines import SubplotZero

def myFun(u,t=0.,mu=.5):
    x = u[0]
    v = u[1]
    dx = v
    dv = mu*(1.-x**2)*v-x
    return (dx,dv)

t = linspace(-5.5,5.5,300)
u0 = array([1.,1.2])
mu = [.1, .2, .5, 1., 1.5, 2.0, 2.5]
fig = figure(figsize=(10,7))
ax = SubplotZero(fig,111)
fig.add_subplot(ax)
ax.grid(True)
for direction in ["right","top"]:
        ax.axis[direction].set_visible(False)
for m in mu:
    u = odeint(myFun,u0,t,args=(m,))
    ax.plot(u[:,0],u[:,1],lw=1.5,label=r'$\mu=%.1f$'%m)
x = linspace(-3,3,15)
y = linspace(-4,4,15)
x,y = meshgrid(x,y)
X,Y = myFun([x,y])
M = (hypot(X,Y))
M[M==0]=1.
X,Y = X/M, Y/M
ax.quiver(x,y,X,Y,M,pivot='mid',cmap=cm.jet)
ax.minorticks_on()
ax.legend(handletextpad=0,loc='upper left')
setp(ax.get_legend().get_texts(),fontsize=12)
fig.savefig("Van_der_pols_equation_phase_portrait.svg",bbox_inches="tight",\
        pad_inches=.15)
show()

# %%
? odeint

# %% [markdown]
# ## Visualizando dados matriciais
#
# O programa abaixo demonstra como criar um plot-bitmap das entradas de uma matriz. Veja como escrever no modo matemático usando a [matplotlib](http://matplotlib.org/users/mathtext.html). Para maiores detalhes sobre o tratamento de imagens consulte a página [scikit-image](http://www.scipy-lectures.org/packages/scikit-image/index.html)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.mlab as mlab    # Comando de compatibilidade com o Matlab
import matplotlib.pyplot as plt
from scipy.interpolate import RectBivariateSpline
# Funções removidas na versão 3.1.0 em diante
# https://matplotlib.org/3.1.1/api/prev_api_changes/api_changes_3.1.0.html?highlight=stineman_interp#removals
    
# Cria uma matriz Z que contém alguns dados interessantes
delta = 0.1
x = y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)

Z = RectBivariateSpline(X, Y, 3.0, 1.0, 0.0, 0.0)
#Z = mlab.bivariate_normal(X, Y, 3.0, 1.0, 0.0, 0.0)

fig = plt.figure(figsize=(10,6))

# Exibe os dados 'raw' da matriz Z em uma figura
ax = fig.add_subplot(121)
#plt.figure(1)
plt.imshow(Z, interpolation='nearest')
plt.title(u'imshow exemplo 1a: sem interpolação')
plt.savefig("pylab-imshow1a.pdf")


# Exibe os dados interpolados em outra figura
ax = fig.add_subplot(122)
#plt.figure(2)
im = plt.imshow(Z, interpolation='bilinear')
plt.title(u'imshow exemplo 1b: com uma interpolação bi-linear')
plt.savefig("pylab-imshow1b.pdf")

# %% [markdown]
# Para usar diferentes cores, usamos o módulo `matplotlib.cm` (onde cm significa Color Map). O código abaixo demonstra como podemos selecionar cores no conjunto de mapas já fornecidos e como podemos modificá-los (reduzindo o número de cores no mapa). O último exemplo imita o comportamento do comando `contour` mais sofisticado que também vem com` matplotlib`.

# %%
import numpy as np
import matplotlib.mlab as mlab    # Comando de compatibilidade com o Matlab
import matplotlib.pyplot as plt
import matplotlib.cm as cm        # Submodulo do mapa de cores

#Cria uma matriz Z que contém alguns dados interessantes
delta = 0.025
x = y = np.arange(-3.0, 3.0, delta)
X, Y  = np.meshgrid(x, y)
Z = mlab.bivariate_normal(X, Y, 3.0, 1.0, 0.0, 0.0)


fig = plt.figure(figsize=(10,8))

Nx, Ny = 2, 3
plt.subplot(Nx, Ny, 1)  # o próximo plot será mostrado no
                        # primeiro subplot da matriz Nx x Ny
                        # dos subplots
        
plt.imshow(Z, cmap=cm.jet)  # padrão: colourmap 'jet'
plt.title("Mapa de cores  jet")

plt.subplot(Nx, Ny, 2)   # o próximo plot para o segundo subplot
plt.imshow(Z, cmap=cm.jet_r)  # cores reversa as do jet
plt.title("Mapa de cores  jet_r")

plt.subplot(Nx, Ny, 3)
plt.imshow(Z, cmap=cm.gray)
plt.title("Mapa de cores  gray")

plt.subplot(Nx, Ny, 4)
plt.imshow(Z, cmap=cm.hsv)
plt.title("Mapa de cores  hsv")

plt.subplot(Nx, Ny, 5)
plt.imshow(Z, cmap=cm.gist_earth)
plt.title("Mapa de cores  gist_earth")

plt.subplot(Nx, Ny, 6)
# Faz isolines reduzindo o número de cores para 10
mycmap = cm.get_cmap('jet', 10)    # 10 cores discretas
plt.imshow(Z, cmap=mycmap)
plt.title(u"Mapa de cores jet\n(só 10 cores)")

plt.savefig("pylab-imshowcm.pdf")

# %% [markdown]
# ### Gráficos de *z* = *f*(*x*, *y*)  e  outras características da Matplotlib
#
# A Matplotlib tem um grande número de recursos e pode criar todos os gráficos padrão (1d e 2d), tais como histogramas, gráficos de pizza, gráficos de dispersão, gráficos de 2d-intensidade (ou seja *z*=*f*(*x*,*y*)) e linhas de contorno) e muito mais. A figura \[fig:pylabcontour\_demo\] mostra esse exemplo (o programa `contour_demo.py` é um exemplo padrão do pacote` pylab`). Este link fornece código fonte para produzir esse tipo de gráfico: [contour\_demo.py] (http://matplotlib.org/examples/pylab_examples/contour_demo.html)
#
# Outros exemplos são:
#
# -  <http://matplotlib.org/users/screenshots.html>
# -  <http://matplotlib.org/gallery.html>
# -  Recentemente, a criação de 3d-plots foi adicionado ao pylab:  <http://matplotlib.org/examples/mplot3d/index.html#mplot3d-examples>
#
# <img src="code/pylab/contour_demo.png" alt="The output of contour_demo.py." style="width:80.0%" />

# %% [markdown]
# ## Tabuleiro de Xadrez

# %%
# %matplotlib inline

# %%
import numpy as np
tabuleiro = np.zeros((9, 9))
tabuleiro[::2, 1::2] = 1
tabuleiro[1::2, ::2] = 1
import matplotlib.pyplot as plt
plt.imshow(tabuleiro, cmap='gray', interpolation='nearest')

# %% [markdown]
# ## Grafícos 3D

# %%
# linha3d.py
# -------------------------------------------------------------------------
# Cria um gráfico paramétrico tridimensional 
# ------------------------------------------------------------------------- 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D     # importa as bibliotecas 3D 

fig = plt.figure()                  # cria uma nova figura
ax = Axes3D(fig)                    # cria um objeto gráfico 3D anexado a figura
t = np.linspace(0, 5*np.pi, 501)    # define os parametros para o gráfico paramétrico 3D
x = t * np.cos(t)
y = t * np.sin(t)

ax.plot(x, y, t)        # gera o gráfico 3D
plt.show()

# %% [markdown]
# Note que foi usado o método `plot` para anexar a um objeto específico. Em seguida criou-se o objeto `Axes3D`, o que  permitiu usar os seus métodos para gerar gráficos tridimensionais. O método `ax.plot` aceita três arrays, cujas entradas correspondentes são interpretadas como as coordenadas $x$, $y$ e $z$ dos pontos a serem desenhados. O objeto gerado pelo `Axes3D (fig)` também pode criar gráficos de superfície, gráficos de contornos tridimensionais, histogramas tridimensionais e muito mais.
#
# Sua tela é bidimensional. Se quer um gráfico "3D", o que você realmente obtém deve ser uma projeção bidimensional - o que uma câmera veria em sua malha de algum ponto de vista externo. Alternar para um ponto de vista diferente pode tornar mais fácil ver o que está acontecendo. Usando o magic `%matplotlib qt` no Jupyter/IPython ele fara o gráfico em uma janela aparte na qual pode-se clicar e arrastar dentro de seu gráfico para alterar o ponto de vista. (Isso depende da parte traseira dos gráficos que você está usando.) Se isso não for possível, você pode alterar o ponto de vista do prompt de comando do Jupyter/IPython ou em um script com o comando `ax.view_init(elev = 30, azim = 30)`. Você especifica o ponto de vista dando a elevação e azimute, em graus - não radianos.
# Por exemplo,

# %%
fig = plt.figure()                  # cria uma nova figura
ax = Axes3D(fig)                    # cria um objeto gráfico 3D anexado a figura
t = np.linspace(0, 5*np.pi, 501)    # define os parametros para o gráfico paramétrico 3D

ax.view_init(elev = 45, azim = 30)
ax.plot(t * np.cos(t), t * np.sin(t), t)        # gera o gráfico 3D
plt.show()

# %%
"""
.. Versão:: 1.1.0
   Esta demonstração depende de novos recursos adicionados ao contourf3d.
"""
# %matplotlib qt5
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.02)
ax.plot_surface(X, Y, Z, rstride=8, cstride=12, alpha=0.3)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %%
# %matplotlib qt5
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)

cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='Curva paramétrica')
ax.legend()

plt.show()

# %% [markdown]
# ## Fazendo o gráfico dos dados de um arquivo

# %%
# %matplotlib notebook

# %%
# !cat data/magnus.dat
# Out:
#     0.000000E+00    0.000000E+00    0.000000E+00
#     0.899527E-02    0.375346E-02    0.899445E-02
#     0.179901E-01    0.751760E-02    0.179868E-01
#     0.269844E-01    0.112924E-01    0.269770E-01
#     0.359783E-01    0.150779E-01    0.359651E-01
#     0.449716E-01    0.188741E-01    0.449512E-01
#     0.539644E-01    0.226809E-01    0.539351E-01
#     0.629568E-01    0.264984E-01    0.629169E-01
#     0.719486E-01    0.303266E-01    0.718966E-01
#     0.809398E-01    0.341655E-01    0.808741E-01
#     0.899305E-01    0.380151E-01    0.898496E-01
#     0.989207E-01    0.418754E-01    0.988230E-01
#     0.107910        0.457464E-01    0.107794
#     0.116899        0.496281E-01    0.116763
#     0.125888        0.535204E-01    0.125730
#     0.134876        0.574235E-01    0.134695
#     0.143863        0.613372E-01    0.143658
#     0.152849        0.652617E-01    0.152619
#     0.161835        0.691969E-01    0.161577
#     0.170821        0.731428E-01    0.170534
# ...

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt


# Leitura do arquivo de dados: Modo python
f = open('data/magnus.dat')
#Para ignorar o cabeçalho faça:
#cabecalho = f.readline()
x = []
y = []
z = []
for line in f.readlines():
    #print (line)
    colunas = line.split()
    #print(colunas)
    x.append(float(colunas[0]))
    y.append(float(colunas[1]))
    z.append(float(colunas[2]))
f.close()

# Agora vamos converter as listas em numpy array:
x = np.array(x)
y = np.array(y)
z = np.array(z)

# Fazendo o gráfico

mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
ax.plot(x, y, z, 'r', label='Efeito Magnus', lw=3)
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">

# %%
# Gráfico do Atrator de Lorenz baseado no artigo de Edward Lorenz de 1963 "Deterministic
# Nonperiodic Flow".
# http://journals.ametsoc.org/doi/abs/10.1175/1520-0469%281963%29020%3C0130%3ADNF%3E2.0.CO%3B2
#
# Nota: Delvido a ela ser uma simples EDO não-linear, seria mais fácil implementar
#       usando a SciPy ode solver, mas a abordagem atual depende somente da Numpy.
 

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


def lorenz(x, y, z, s=10, r=28, b=2.667):
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot


dt = 0.01
stepCnt = 10000

# Precisa de mais um para os valores iniciais
xs = np.empty((stepCnt + 1,))
ys = np.empty((stepCnt + 1,))
zs = np.empty((stepCnt + 1,))

# Definição de valores iniciais
xs[0], ys[0], zs[0] = (0., 1., 1.05)

# Passando pelo "tempo".
for i in range(stepCnt):
    # Derivadas dos estados de X, Y, Z
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")
ax.set_zlabel("Eixo Z")
ax.set_title(" Atrator de Lorenz")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">

# %%
'''
=================================
Superfícies 3D com coordenadas polares
=================================

Demonstra traçando uma superfície definida em coordenadas polares. 
Usa a versão invertida do mapa de cores YlGnBu. Também demonstra a 
escrita de legendas dos eixo com o modo matemático do LaTeX.

Exemplo contribuído por Armin Moser.

'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import numpy as np


fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

# Criar a malha em coordenadas polares e calcular Z correspondente.
r = np.linspace(0, 1.25, 50)
p = np.linspace(0, 2*np.pi, 50)
R, P = np.meshgrid(r, p)
Z = ((R**2 - 1)**2)

# Expressa a malha no sistema cartesiano.
X, Y = R*np.cos(P), R*np.sin(P)

# Faz o gráficop da superfície.
ax.plot_surface(X, Y, Z, cmap=plt.cm.YlGnBu_r)

# Ajustar os limites e adicionar as legendas matemáticas do LaTeX.
ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">

# %% [markdown]
# ## Curvaturas Gaussianas
#
# Imagens da [curvatura gaussiana](https://commons.wikimedia.org/wiki/File:Gaussian_curvature.svg), usada mais especificamente [Curvatura gaussiana](https://ca.wikipedia.org/wiki/Curvatura_Gaussiana).

# %%
# %matplotlib inline
#from __future__ import division
import numpy as np
from numpy import pi, cos, sin, sqrt, outer, ones
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
u = np.linspace(0, 2 * pi, 100)
v = np.linspace(0, pi, 100)
one_v = ones(100)


# Esfera
x1 = 10 * outer(cos(u), sin(v))
y1 = 10 * outer(sin(u), sin(v)) + 17
z1 = 10 * outer(one_v, np.cos(v))
ax.plot_surface(x1, y1, z1, rstride=5, cstride=5, cmap='Spectral',
                linewidth=0.5)

# Cilindro
x2 = 6 * outer(cos(u), one_v)
y2 = 6 * outer(sin(u), one_v)
z2 = 20 * outer(one_v, v/pi - 0.5)
ax.plot_surface(x2, y2, z2, rstride=5, cstride=5, cmap='Spectral',
                linewidth=0.5)

# Hiperbolóide
v = 2*v/pi - 1
x3 = 6 * outer(cos(u), sqrt(1 + v**2))
y3 = 6 * outer(sin(u), sqrt(1 + v**2)) - 16
z3 = 12 * outer(one_v, v)
ax.plot_surface(x3, y3, z3, rstride=5, cstride=5, cmap='Spectral',
                linewidth=0.5)

# Fixa a razão entre tamanhos e alguns detalhes dos eixos
ax.set_xlim(-13, 13)
ax.set_ylim(-13, 13)
ax.set_zlim(-13, 13)
ax.view_init(elev=35, azim=-45)
plt.axis('off')
plt.savefig('Gaussian_curvature.svg', transparent=True)
plt.show()

# %% [markdown]
# ## Módulo de animação da Matplotlib <a name="MPL-Mod-Anim"></a>
#
# Essa é uma reprodução da documentação oficial da Matplotlib: [Animation](http://matplotlib.org/api/animation_api.html)
# Há também um excelente tutorial do *Jake VanderPlas* [Pythonic Perambulations](https://jakevdp.github.io/blog/2012/08/18/matplotlib-animation-tutorial/)
#
#  - [Triple Pendulum CHAOS!](http://jakevdp.github.io/blog/2017/03/08/triple-pendulum-chaos/)
#
# ### Sumário
#
# - Animation
# - Writer Classes
# - Helper Classes
# - Inheritance Diagrams
# - Deprecated

# %% [markdown]
# ### Animação
#
# A maneira mais fácil de fazer uma animação na matplotlib é usar uma das classes de animação.
#
# - `FuncAnimation` Faz uma animação chamando repetidamente uma função func.
#
# - `ArtistAnimation` Anima usando um conjunto fixo de objetos `Artist`.
#
# Em ambos os casos, é fundamental manter uma referência ao objeto de instância. A animação é avançada por um temporizador (normalmente a partir da estrutura de GUI do ambiente usado) na qual o objecto de `Animation` contém a referência apenas para ele. Se você não mantiver uma referência ao objeto `Animation`, ele (e, portanto, os temporizadores), será coletado lixo o que irá parar a animação.
#
# ### Para salvar uma animação no disco
#
# - `Animation.save` Salva um arquivo de filme desenhando cada quadro.
#
# - `Animation.to_html5_video` Retorna a animação como uma tag de vídeo HTML5.
#
# Consulte [Classes auxiliares](http://matplotlib.org/api/animation_api.html#ani-writer-classes) abaixo para obter detalhes sobre quais formatos de filme são suportados.

# %% [markdown]
# ### FuncAnimation
#
# O funcionamento interno da FuncAnimation é mais ou menos:

# %% [markdown]
# ```python
# for d in frames:
#    artists = func(d, *fargs)
#    fig.canvas.draw_idle()
#    plt.pause(interval)
# ```

# %% [markdown]
# Com detalhes para lidar com "blitting" (para melhorar drasticamente o desempenho ao vivo), para ser não-bloqueado, para lidar com repetições, com vários eixos animados e salvar facilmente a animação para um arquivo de filme.
#
# "Blitting" é uma técnica antiga em computação gráfica. A essência geral é tomar um mapa de bits existente (no nosso caso uma figura principalmente rasterizada) e, em seguida, 'blit' mais um artista no topo. Assim, ao gerenciar um bitmap "limpo" salvo, só podemos re-desenhar os poucos artistas que estão mudando em cada quadro e, possivelmente, economizar quantidades significativas de tempo. Ao usar blitting (passando blit = True) o núcleo do loop de FuncAnimation fica um pouco mais complicado

# %% [markdown]
# ```python
# ax = fig.gca()
#
# def update_blit(artists):
#     fig.canvas.restore_region(bg_cache)
#     for a in artists:
#         a.axes.draw_artist(a)
#
#     ax.figure.canvas.blit(ax.bbox)
#
# artists = init_func()
#
# for a in artists:
#    a.set_animated(True)
#
# fig.canvas.draw()
# bg_cache = fig.canvas.copy_from_bbox(ax.bbox)
#
# for f in frames:
#     artists = func(f, *fargs)
#     update_blit(artists)
#     plt.pause(interval)
# ```

# %% [markdown]
# Isto é, naturalmente, deixar de fora muitos detalhes (como a atualização do plano de fundo quando a figura é redimensionada ou totalmente re-desenhado). No entanto, neste exemplo minimalista  espero dár uma idéia de como as funções `init_func` e `func` são usados dentro de `FuncAnimation` e um pouco da teoria de como 'blitting' funciona.
#
# A assinatura esperada em `func` e `init_func` é muito simples para manter `FuncAnimation` fora de sua lógica de consertos e tramas, mas isso significa que os objetos que você pode passar devem saber em que artistas eles devem estar trabalhando. Existem várias abordagens para lidar com isso, de complexidade variável e encapsulamento. A abordagem mais simples, que funciona muito bem no caso de um script, é definir o artista em um escopo global e deixar Python resolver as coisas.
#
# Para incluir uma animação no notebook, siga, as instruções abaixo, maiores detalhes podem ser encontrados no blog [Embedding Matplotlib Animations in Jupyter Notebooks](http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/) do Louis Tiao.
#
# Em seu blog [Embedding Matplotlib Animations in IPython Notebooks](http://jakevdp.github.io/blog/2013/05/12/embedding-matplotlib-animations/) Jake VanderPlas apresenta um truque para incorporar as animações da Matplotlib nos IPython Notebooks, que envolve gravá-lo como um vídeo para um tempfile e, em seguida, recodificá-lo em Base64 como um vídeo HTML5.
#
# Infelizmente (ou melhor, felizmente), este hack já está obsoleto pelos pesados esforços de desenvolvimento dedicados tanto na Matplotlib quanto no IPython Notebook (este foi renomeado para o Jupyter Notebook) nos últimos anos. Em particular, a Matplotlib 1.5.1 agora suporta a exibição em linha de animações no notebook com o método to_html5_video, que converte a animação em um vídeo codificado em h264 e incorpora-o diretamente no notebook.
#
# Neste trecho, reproduzimos os blog de Louis Tiao e Jake VanderPlas com este novo recurso.

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# %%
# Primeiro configure a figura, o eixo e o elemento de gráfico 
# que queremos animar
fig, ax = plt.subplots(figsize=(10,6))

ax.set_xlim(( 0, 2))
ax.set_ylim((-1.1, 1.1))

line, = ax.plot([], [], lw=2)

# %%
# Função de inicialização: plot o plano de fundo de cada quadro
def init():
    line.set_data([], [])
    return (line,)

# %%
# Função animação. Essa é chamada sequencialmente
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# %%
# Chama o animador. blit=True significa apenas re-desenhar as peças que foram alteradas.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=40, blit=True, repeat=False)

# Em um programa python fora do ambiente do notebook
# chame o vídeo:
# anim

# %%
# Para visualizar no notebook
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="432" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# Observe que as instâncias de Animação agora têm um método `_repr_html_`. No entanto, ele retorna Nenhum por padrão.

# %%
anim._repr_html_() is None
# Out:
# True

# %% [markdown]
# Isso significa que não obteremos qualquer tipo de animação a partir da exibição em linha.

# %%
anim

# %% [markdown]
# O método usado para exibir é controlado pelo parâmetro animation.html rc, que atualmente suporta valores de none e html5. None é o padrão, sem exibição. Nós simplesmente precisamos configurá-lo para html5:

# %%
# equivalente a rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="720" height="432" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# Um exemplo de animação completa

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib import animation, rc
from IPython.display import HTML

u=np.linspace(0, 2*np.pi, 128)
v=np.sin(u)

fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro', animated=True)


def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1.05, 1.05)
    ln, = plt.plot(u, v, 'g', animated=True)
    return ln,

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln,

# para gerar a animação no notebook
rc('animation', html='html5')

ani = FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 80),
                    init_func=init, blit=True, repeat=False)

ani

#plt.show()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
""" Faz uma animação dos passo de um passeio aleatório bidimensional. """
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from numpy.random import random as rand

# Define o número de passos para cada passeio aleatório.
n_passos = 150

# Cria uma figura vazia com o tamanho desejado.
limite = 20
fig = plt.figure()      # must have figure object for movie
ax = plt.axes(xlim=(-limite, limite), ylim=(-limite, limite))

# Cria uma linha e um ponto sem dados.  Eles serão adaptados
# durante cada frame da animação. 
(a_linha,) = ax.plot([], [], lw=2)             # linha para mostrar a trajetória
(o_ponto,) = ax.plot([], [], 'ro', ms=9)       # ponto para mostra a posição atual

# Gera os dados do passeio aleatório.
x_passos = 2*(rand(n_passos) < 0.5) - 1     # gera passos aleatórios +/- 1
y_passos = 2*(rand(n_passos) < 0.5) - 1
x_coordenada = x_passos.cumsum()             # soma os passos para obter a posição
y_coordenada = y_passos.cumsum()

# Essa função irá gerar cada frame da animação.
# Ela adiciona todos os dados através do frame n para uma linha
# e move um ponto para a n-ésima posição do passeio. 
def get_step(n, x, y, Essa_linha, Esse_ponto):
    Essa_linha.set_data(x[:n+1], y[:n+1])
    Esse_ponto.set_data(x[n], y[n])

# Chama a função animation.FuncAnimation e cria o filme.
anim = animation.FuncAnimation(fig, get_step, frames=n_passos, \
                    fargs=(x_coordenada,y_coordenada,a_linha,o_ponto) )

# Salva o filme no diretório atual.
# *** ESTA CAUSARÁ UM ERRO A MENOS QUE FFMPEG OU MENCODER ESTEJAM INSTALADOS. ***
# my_movie.save('random_walk.mp4', fps=30)

HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# O segundo método é para nós functools.partial para 'ligar' artistas para funcionar. Um terceiro método é usar fechamentos para construir os artistas necessários e funções. Um quarto método é criar uma classe.

# %%
"""
=====
Decaimento
=====

Esse exemplo mostra uma animação de um decaimento sinusoidal.
"""


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation


def data_gen(t=0):
    cnt = 0
    while cnt < 1000:
        cnt += 1
        t += 0.1
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)


def init():
    ax.set_ylim(-1.1, 1.1)
    ax.set_xlim(0, 10)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(data):
    # update the data
    t, y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, data_gen, blit=True, interval=40,
                              repeat=False, init_func=init)

ani
#plt.show()
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
! mkdir -p Animacoes
# !ls Animacoes/

# %%
# !python3.5 Animacoes/basic_example.py

# %%
# !ls ../Matplotlib/

# %%
# !python3.5 ../Matplotlib/double_pendulum_animated.py

# %%
# %matplotlib inline

# %%
"""
===========================
O problema do pendulo duplo
===========================

Essa animação ilustra o problema do pendulo duplo.
"""

# Pendulo duplo, o foi código foi adaptado do seguinte código em C:
# http://www.physics.usyd.edu.au/~wheat/dpend_html/solve_dpend.c

from numpy import sin, cos
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import matplotlib.animation as animation

from matplotlib import animation, rc
from IPython.display import HTML

G  = 9.8  # acceleration due to gravity, in m/s^2
L1 = 1.0  # length of pendulum 1 in m
L2 = 1.0  # length of pendulum 2 in m
M1 = 1.0  # mass of pendulum 1 in kg
M2 = 1.0  # mass of pendulum 2 in kg


def derivs(state, t):

    dydx = np.zeros_like(state)
    dydx[0] = state[1]

    del_ = state[2] - state[0]
    den1 = (M1 + M2)*L1 - M2*L1*cos(del_)*cos(del_)
    dydx[1] = (M2*L1*state[1]*state[1]*sin(del_)*cos(del_) +
               M2*G*sin(state[2])*cos(del_) +
               M2*L2*state[3]*state[3]*sin(del_) -
               (M1 + M2)*G*sin(state[0]))/den1

    dydx[2] = state[3]

    den2 = (L2/L1)*den1
    dydx[3] = (-M2*L2*state[3]*state[3]*sin(del_)*cos(del_) +
               (M1 + M2)*G*sin(state[0])*cos(del_) -
               (M1 + M2)*L1*state[1]*state[1]*sin(del_) -
               (M1 + M2)*G*sin(state[2]))/den2

    return dydx

# create a time array from 0..100 sampled at 0.05 second steps
dt = 0.05
t = np.arange(0.0, 50, dt)

# th1 and th2 are the initial angles (degrees)
# w10 and w20 are the initial angular velocities (degrees per second)
th1 = 120.0
w1  = 0.0
th2 = -10.0
w2  = 0.0

# initial state
state = np.radians([th1, w1, th2, w2])

# integrate your ODE using scipy.integrate.
y = integrate.odeint(derivs, state, t)

x1 = L1*sin(y[:, 0])
y1 = -L1*cos(y[:, 0])

x2 = L2*sin(y[:, 2]) + x1
y2 = -L2*cos(y[:, 2]) + y1

fig = plt.figure()
ax = fig.add_subplot(111, autoscale_on=False, xlim=(-2, 2), ylim=(-2, 2))
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)


def init():
    line.set_data([], [])
    time_text.set_text('')
    return line, time_text


def animate(i):
    thisx = [0, x1[i], x2[i]]
    thisy = [0, y1[i], y2[i]]

    line.set_data(thisx, thisy)
    time_text.set_text(time_template % (i*dt))
    return line, time_text

# para gerar a animação no notebook
rc('animation', html='html5')

pendulo_duplo_animado = animation.FuncAnimation(fig, animate, np.arange(1, len(y)),
                              interval=25, blit=True, init_func=init)

pendulo_duplo_animado.save('Pendulo_duplo.mp4', fps=15)
pendulo_duplo_animado
#plt.show()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
